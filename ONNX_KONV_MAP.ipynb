# %%
# %% Cell 1: Imports
from Helper.onnx_konv import *
import json
import os

# %%
# %% Cell 2: Parameter, Ordnerpfade, Modellauswahl, Klassenanzahl, Cache-Datei und Batch-Größe

best_checkpoints_json = "FINAL_DATEN/best_checkpoints_Mapillary_small.json"
calibration_data = "Mapillary_Vistas/training/images"
output_dir = "onnx_models_mapillary_small"
num_classes = 124
calibration_cache_file = "Kalibr_Cache/cache_file.h5"
calibration_batch_size = 5  # Hier definierst du, wie viele Bilder pro Batch geladen werden sollen

with open(best_checkpoints_json, "r") as f:
    best_checkpoints = json.load(f)

model_names = sorted(best_checkpoints.keys())
print("Gefundene Modelle im angegebenen Ordnerpfad:")
for idx, name in enumerate(model_names, start=1):
    print(f"[{idx}] {name}")

conversion_mapping = {
    1: ["fp32"],
    2: ["fp32", "fp16"],
    3: ["fp32", "fp16", "int8_dynamic"],
    4: ["fp32", "fp16", "int8_calibrated"],
    5: ["fp32", "fp16", "int8_dynamic", "int8_calibrated"]
}
print("\nUmrechnungscodes:")
for code, convs in conversion_mapping.items():
    print(f"  {code}: {', '.join(convs)}")
# Out:
# Gefundene Modelle im angegebenen Ordnerpfad:
# [1] deeplabv3_resnet101
# [2] deeplabv3_resnet50
# [3] fcn_resnet101
# [4] fcn_resnet50
#
# Umrechnungscodes:
#   1: fp32
#   2: fp32, fp16
#   3: fp32, fp16, int8_dynamic
#   4: fp32, fp16, int8_calibrated
#   5: fp32, fp16, int8_dynamic, int8_calibrated

# %%
# %% Cell 3A: Benutzereingaben & Steuerung
# Steuerung der Ausführung:
# run_all = True: Alle Modelle in allen Varianten (Code 5) werden konvertiert.
# Alternativ: Mit selected_model_indices und selected_conversion_codes gezielt auswählen.
run_all = False
selected_model_indices = [1, 2, 3, 4]      # Beispiel: 1. und 3. Modell
selected_conversion_codes = [3, 3, 3, 3]     # Beispiel: Modell 1 mit Code 2 (FP32+FP16), Modell 3 mit Code 4 (FP32+INT8 calibrated)

# %%
# %% Cell 3B: Funktionsdefinitionen (kollabierbar)
def convert_and_test_model(checkpoint_path, model_name, conversion_types, calibration_data_path, num_classes):
    """
    Führt für das angegebene Modell (über den Checkpoint) die gewünschten Konvertierungen durch
    und testet anschließend alle erfolgreich konvertierten Modelle.
    
    :param checkpoint_path: Pfad zum Checkpoint (z. B. eine pickle-Datei)
    :param model_name: Name des Modells
    :param conversion_types: Liste der gewünschten Konvertierungen (z. B. ["fp32", "fp16", "int8_dynamic", "int8_calibrated"])
    :param calibration_data_path: Pfad zu den Kalibrierungsbildern (wichtig für INT8)
    :param num_classes: Anzahl der Klassen, die im Modell verwendet werden sollen
    """
    print(f"\n=== Starte Konvertierung für Modell: {model_name} ===")
    
    # Erstelle einen Converter (MapillaryONNXModelConverter nutzt hier den HDF5-Loader, falls calibration_cache_file existiert)
    converter = MapillaryONNXModelConverter(
        checkpoint_path=checkpoint_path,
        model_name=model_name,
        width=2048,
        height=1024,
        input_shape=(1, 3, 520, 520),
        num_classes=num_classes,
        dynamic_batch=True,
        opset_version=13,
        output_dir=output_dir,
        skip_local_load=True,
        calibration_cache_file=calibration_cache_file  # Hier wird der Cache-Pfad übergeben
    )
    
    # Modell laden
    try:
        converter.load_model()
    except Exception as e:
        print(f"[ERROR] Laden des Modells {model_name} fehlgeschlagen: {e}")
        return
    
    converted_paths = {}
    
    # FP32-Export
    if "fp32" in conversion_types or any(conv in conversion_types for conv in ["fp16", "int8_dynamic", "int8_calibrated"]):
        try:
            fp32_path = converter.export_fp32()
            converted_paths["fp32"] = fp32_path
        except Exception as e:
            print(f"[ERROR] FP32-Export von {model_name} fehlgeschlagen: {e}")
            return

    # FP16-Konvertierung
    if "fp16" in conversion_types:
        if HAS_FLOAT16_CONVERTER:
            try:
                fp16_path = converter.convert_fp16(fp32_path)
                converted_paths["fp16"] = fp16_path
            except Exception as e:
                print(f"[WARN] FP16-Konvertierung von {model_name} fehlgeschlagen: {e}")
        else:
            print("[WARN] FP16-Konvertierung nicht verfügbar (float16_converter fehlt).")
    
    # Dynamische INT8-Quantisierung
    if "int8_dynamic" in conversion_types:
        try:
            int8_dyn_path = converter.quantize_int8_dynamic(fp32_path)
            converted_paths["int8_dynamic"] = int8_dyn_path
        except Exception as e:
            print(f"[ERROR] Dynamische INT8-Quantisierung von {model_name} fehlgeschlagen: {e}")
    
    # Kalibrierte INT8-Quantisierung (nutzt den HDF5-Loader, falls Cache vorhanden, ansonsten den Lazy-Loader)
    if "int8_calibrated" in conversion_types:
        try:
            int8_cal_path = converter.quantize_int8_calibrated(
                fp32_onnx_path=fp32_path,
                calibration_data_path=calibration_data_path,
                input_tensor_name="input",
                max_samples=200
            )
            converted_paths["int8_calibrated"] = int8_cal_path
        except Exception as e:
            print(f"[ERROR] Kalibrierte INT8-Quantisierung von {model_name} fehlgeschlagen: {e}")
    
    # Teste alle erfolgreich konvertierten Modelle
    print(f"\n>>> Teste konvertierte Modelle für {model_name}:")
    for conv, path in converted_paths.items():
        try:
            print(f"{conv.upper()} Modell:")
            converter.test_model(path)
        except Exception as e:
            print(f"[ERROR] Testen des {conv.upper()} Modells von {model_name} fehlgeschlagen: {e}")
    
    print(f"=== Konvertierung für {model_name} abgeschlossen ===\n")

# %%
# %% Cell 3C: Ausführung & Ausgabe
if run_all:
    for model_name in model_names:
        checkpoint_path = best_checkpoints[model_name]
        print(f"\n[RUN_ALL] Konvertiere Modell '{model_name}' mit allen Varianten...")
        convert_and_test_model(checkpoint_path, model_name, conversion_mapping[5], calibration_data, num_classes)
else:
    if len(selected_model_indices) != len(selected_conversion_codes):
        print("[ERROR] Die Listen selected_model_indices und selected_conversion_codes müssen gleich lang sein!")
    else:
        for idx, conv_code in zip(selected_model_indices, selected_conversion_codes):
            model_idx = idx - 1
            if model_idx < 0 or model_idx >= len(model_names):
                print(f"[ERROR] Ungültige Modellnummer: {idx}")
                continue
            model_name = model_names[model_idx]
            checkpoint_path = best_checkpoints[model_name]
            conversion_types = conversion_mapping.get(conv_code)
            if conversion_types is None:
                print(f"[ERROR] Ungültiger Umrechnungscode: {conv_code} für Modell '{model_name}'")
                continue
            print(f"\n[SELECTED] Konvertiere Modell '{model_name}' mit Umrechnungscode {conv_code} ({', '.join(conversion_types)})...")
            convert_and_test_model(checkpoint_path, model_name, conversion_types, calibration_data, num_classes)
# Out:
# [SELECTED] Konvertiere Modell 'deeplabv3_resnet101' mit Umrechnungscode 3 (fp32, fp16, int8_dynamic)...
#
# === Starte Konvertierung für Modell: deeplabv3_resnet101 ===
# Initialisierung abgeschlossen. Gerät: cuda. Ausgabeordner: onnx_models_mapillary_small
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2025-03-16 19:12:47.469245: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-16 19:12:48.781653: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using CUDA GPU
# Model loaded: deeplabv3_resnet101 | Device: cuda
# Modell deeplabv3_resnet101 erfolgreich geladen und auf cuda platziert.
# FP32 ONNX-Modell exportiert: onnx_models_mapillary_small/deeplabv3_resnet101_fp32.onnx
# Starte FP16-Konvertierung: onnx_models_mapillary_small/deeplabv3_resnet101_fp32.onnx
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.900863629725454e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.113879412999452e-19 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.235761620283938e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.642750191384407e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.508489082772729e-16 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.9488869185124713e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.1710153240309202e-16 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.1200407489162584e-18 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.348933219626815e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.528920435570478e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.1259578474665313e-14 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.509400200613527e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.978122811471115e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.876518514433021e-16 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.509365384019475e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 7.508945753920392e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.462497623105775e-19 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.398177276878414e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.073606206137058e-18 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.791362404177896e-18 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 7.318512018628098e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.944219884033373e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.078589323170499e-14 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.836620114085464e-14 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.853226694020134e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.7422445329783842e-17 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.51639322104802e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.5236833062620692e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.06819088764687e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 7.728687134722634e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.56119283956491e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.209280225429211e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.02294556197093e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.705352660393e-17 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.756463039574555e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.371224963353025e-18 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.2138155266244044e-18 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.756419696467674e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.2226756608037237e-13 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.477005095919942e-13 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.323399297045398e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.0233676067960005e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.161542054609269e-16 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.773101596787315e-16 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.275148471488137e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.3632059744785166e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.6807995718444752e-17 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.665200740802902e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.717293109149898e-14 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.26405710985239e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.7364366848159236e-14 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.4216579955992245e-14 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.175445851764323e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.39079822448052e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.511692873800712e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.822944817320149e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.356800253901838e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.753081140838276e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.542944757688019e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.051189760748153e-18 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.9918070744552253e-18 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.033919947550203e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.6068527196940393e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.5798021100910487e-17 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.033919592278835e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.1935893625466404e-13 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.261376608850735e-14 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.7006284380727266e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.2346323963186023e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.4251633577770613e-17 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.3852471117986659e-18 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.4460976567073374e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.6906090163102423e-13 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.8682696719968944e-13 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.532191593715652e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.167419479176551e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.1892921738228062e-15 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.616368915078995e-13 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.128747686961033e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.9760361286435e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.881977063078466e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.813141588985348e-16 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.643783851865152e-16 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.8619062415052854e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.526900431397866e-13 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.587967706801919e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.4276692716642886e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.786492559663682e-16 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.908627753736795e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.7629774029526146e-10 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.017122444745837e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.586559523558513e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.5941057545955764e-15 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.7279573605311072e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.807186865432353e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.084474542447424e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.782628668768666e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.0685210286906997e-16 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.2529748672819568e-15 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.924195954823183e-11 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.9388449139522432e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 7.9201846858723e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.370394617898455e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.8552754321190194e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.833999030530163e-16 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.887299758284726e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.0233932624947872e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.87702853447081e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.979411810130841e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.868135517095695e-15 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.13193981011491e-14 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.930227225421248e-11 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.5482113854825563e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.1002330541364245e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.553680347882619e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.9076130392269306e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.68810284931709e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.899115335632587e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.2712958463723112e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.143675790326597e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.361369766390453e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.653770702134352e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.2085031581298153e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.864319613773205e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.668262469451292e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.745511373802856e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.7401192708987878e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.6312950424388646e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.530358227976649e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.464083230322103e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.80684106460194e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.801210558483035e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.826549909215828e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.882810765773684e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 7.632117871025912e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.3468329501952212e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.3698384648819228e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.668147278787728e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.668456128811613e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.478512659668922e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.138515721929252e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.1838012792253494e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.477655244476523e-10 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.965701450032611e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.881575321746823e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.150221499799045e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.7715683081908082e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.091580821518619e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.7410897612535337e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.646795221357024e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.693077120838552e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.564499974016087e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.668801985488244e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.7591728962429443e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.160367771457231e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.0796973093363249e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.0446401904905542e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.318219571861846e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.910539861517464e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.2102644220135517e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.848441204075016e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.7380495931362816e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.0503344799749357e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.1614711414864587e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.563995333242474e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 4.908853412644021e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.997453047408726e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.6974499078846748e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.8475971863551877e-09 will be truncated to -1e-07
# ...
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.742943844806888e-10 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.1140808761633814e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.1898249496766766e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.9212281543445897e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.499210059018878e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.058383407639198e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.503560644044999e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.698746339381614e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.329651360710727e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.063292563001198e-10 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.0563515395745071e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 8.211802082769282e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.9335972822887015e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -9.585179761018026e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.610924702637021e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.5814969776470345e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -8.292680778176909e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.214167148575143e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.843137601714178e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.7967555354946327e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 5.202851482977167e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.8630408023295786e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.6933682900344138e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.9220510559813118e-12 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.6775396176338386e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.5702935335658594e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.007925185651629e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.911248486725526e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.2318957160785404e-13 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.3555326566078163e-12 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 2.5851793594711125e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -4.729857394636383e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.98885312242237e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.4061659331664487e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.4379772927952672e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.956248199685433e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.431645888620551e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.671372147579405e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.1523355603060281e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -6.95088431257318e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 9.013260893198094e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -3.244738522312218e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.9109962501318023e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -5.457872376268824e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 3.893226629969604e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -2.8136875052098276e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.883347308279554e-08 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.2627714873758578e-08 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.73227348815908e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 6.73345734725217e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -1.1721137394005154e-09 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:43: UserWarning: the float32 number 1.4880535692540775e-09 will be truncated to 1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(pos_min, min_positive_val))
# /home/jan/anaconda3/envs/studi/lib/python3.9/site-packages/onnxconverter_common/float16.py:53: UserWarning: the float32 number -7.98828225789805e-11 will be truncated to -1e-07
#   warnings.warn("the float32 number {} will be truncated to {}".format(neg_max, -min_positive_val))
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# FP16 ONNX-Modell gespeichert: onnx_models_mapillary_small/fcn_resnet50_fp32_fp16.onnx
# Starte dynamische INT8-Quantisierung: onnx_models_mapillary_small/fcn_resnet50_fp32.onnx
# Dynamisch quantisiertes INT8-Modell gespeichert: onnx_models_mapillary_small/fcn_resnet50_fp32_int8_dynamic.onnx
#
# >>> Teste konvertierte Modelle für fcn_resnet50:
# FP32 Modell:
# Teste Modell onnx_models_mapillary_small/fcn_resnet50_fp32.onnx mit Eingabeform (1, 3, 520, 520)
# Inferenz erfolgreich. Ausgabeformen:
#  - Output 0: shape = (1, 124, 520, 520)
# FP16 Modell:
# Teste Modell onnx_models_mapillary_small/fcn_resnet50_fp32_fp16.onnx mit Eingabeform (1, 3, 520, 520)
# Inferenz erfolgreich. Ausgabeformen:
#  - Output 0: shape = (1, 124, 520, 520)
# INT8_DYNAMIC Modell:
# Teste Modell onnx_models_mapillary_small/fcn_resnet50_fp32_int8_dynamic.onnx mit Eingabeform (1, 3, 520, 520)
# Inferenz erfolgreich. Ausgabeformen:
#  - Output 0: shape = (1, 124, 520, 520)
# === Konvertierung für fcn_resnet50 abgeschlossen ===
