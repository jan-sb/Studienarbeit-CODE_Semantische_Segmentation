# %%
import os
import glob
import json
import torch
import numpy as np

# Anzahl der Klassen (Cityscapes)
NUM_CLASSES = 20

# Dictionary mit Klassennamen
city_classes = {
    0: 'road',
    1: 'sidewalk',
    2: 'building',
    3: 'wall',
    4: 'fence',
    5: 'pole',
    6: 'traffic light',
    7: 'traffic sign',
    8: 'vegetation',
    9: 'terrain',
    10: 'sky',
    11: 'person',
    12: 'rider',
    13: 'car',
    14: 'truck',
    15: 'bus',
    16: 'train',
    17: 'motorcycle',
    18: 'bicycle',
    19: 'unlabeled',
}

# Basisverzeichnis
BASE_PATH = "/home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation"
# Ordner, in dem die Confusion Matrices für K-Fold liegen (z.B. Fold0, Fold1, ...)
CONF_MATRIX_BASE = os.path.join(BASE_PATH, "FINAL_DATEN", "confusion_matrices_k_fold")

# Dateiname für die JSON-Ausgabe
OUTPUT_JSON = os.path.join(BASE_PATH, "FINAL_DATEN", "evaluation_results_k_fold.json")

print("CONF_MATRIX_BASE:", CONF_MATRIX_BASE)
print("OUTPUT_JSON:", OUTPUT_JSON)
# Out:
# CONF_MATRIX_BASE: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/confusion_matrices_k_fold
# OUTPUT_JSON: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/evaluation_results_k_fold.json

# %%
def compute_confusion_matrix_metrics(cm):
    """
    Berechnet Mean IoU, FWIoU und pro-Klassen IoU, sowie die relative Häufigkeit jeder Klasse.
    Gibt ein Dictionary mit den wichtigsten Werten zurück.
    """
    # Intersection, Union, etc.
    intersection = torch.diag(cm).float()
    ground_truth_sum = cm.sum(1).float()
    predicted_sum = cm.sum(0).float()
    union = ground_truth_sum + predicted_sum - intersection + 1e-6
    
    iou_per_class = intersection / union
    mIoU = torch.mean(iou_per_class).item()
    
    # Frequency Weighted IoU
    total_pixels = cm.sum().float() + 1e-6
    fwiou = (ground_truth_sum * iou_per_class).sum().item() / total_pixels.item()
    
    # Relative Häufigkeit (Frequency in %)
    frequency_percent = (ground_truth_sum / total_pixels) * 100.0
    
    return {
        "mIoU": mIoU,
        "FWIoU": fwiou,
        "iou_per_class": iou_per_class,
        "frequency_percent": frequency_percent
    }

# %%
NUM_FOLDS = 5  # Wir gehen davon aus, dass es 5 Folds (0..4) gibt
results_summary = {}  # Speichert die Metriken pro Fold und Modell
miou_std_summary = {}  # Speichert die mIoU-Standardabweichungen pro Modell
fwiou_std_summary = {}  # Speichert die FWIoU-Standardabweichungen pro Modell
miou_avg_summary = {}  # Speichert den durchschnittlichen mIoU pro Modell
fwiou_avg_summary = {}  # Speichert den durchschnittlichen FWIoU pro Modell

# Daten sammeln
for fold in range(NUM_FOLDS):
    fold_dir = os.path.join(CONF_MATRIX_BASE, f"Fold{fold}")
    if not os.path.isdir(fold_dir):
        print(f"[WARNING] Ordner {fold_dir} existiert nicht. Überspringe Fold {fold}.")
        continue
    
    cm_files = glob.glob(os.path.join(fold_dir, "*_confusion_matrix.pt"))
    print(f"\n=== Fold {fold}: {len(cm_files)} Confusion Matrices gefunden ===")
    
    fold_results = {}
    
    for cm_file in cm_files:
        base_name = os.path.basename(cm_file)
        model_name = base_name.replace("_confusion_matrix.pt", "")
        
        cm = torch.load(cm_file)
        metrics = compute_confusion_matrix_metrics(cm)
        
        fold_results[model_name] = {
            "mIoU": metrics["mIoU"],
            "FWIoU": metrics["FWIoU"],
            "iou_per_class": metrics["iou_per_class"].cpu().tolist(),
            "frequency_percent": metrics["frequency_percent"].cpu().tolist(),
        }
        
        print(f"\nModell: {model_name}")
        print(f"Mean IoU: {metrics['mIoU']:.4f}")
        print(f"FWIoU: {metrics['FWIoU']:.4f}")
        
        print("\nPer-Klassen Metriken:")
        print("{:<12} {:<40} {:>10} {:>15}".format("Class Index", "Class Name", "IoU", "Frequency (%)"))
        print("-"*70)
        
        iou_values = metrics["iou_per_class"]
        freq_values = metrics["frequency_percent"]
        
        for i in range(NUM_CLASSES):
            class_name = city_classes.get(i, f"Class {i}")
            print("{:<12} {:<40} {:>10.4f} {:>15.2f}".format(
                i,
                class_name,
                iou_values[i].item(),
                freq_values[i].item()
            ))
    
    results_summary[f"Fold{fold}"] = fold_results

# Berechne Standardabweichung und Durchschnitt über alle Folds
all_models = set()
for fold_data in results_summary.values():
    all_models.update(fold_data.keys())

for model_name in all_models:
    miou_list = []
    fwiou_list = []
    
    for fold_data in results_summary.values():
        if model_name in fold_data:
            miou_list.append(fold_data[model_name]["mIoU"])
            fwiou_list.append(fold_data[model_name]["FWIoU"])
    
    if miou_list:
        miou_std_summary[model_name] = float(np.std(miou_list))
        fwiou_std_summary[model_name] = float(np.std(fwiou_list))
        miou_avg_summary[model_name] = float(np.mean(miou_list))
        fwiou_avg_summary[model_name] = float(np.mean(fwiou_list))

# Kombiniere alles zu einem JSON-Dokument
output_json_data = {
    "folds": results_summary,
    "summary": {
        model: {
            "avg_mIoU": miou_avg_summary.get(model, None),
            "std_mIoU": miou_std_summary.get(model, None),
            "avg_FWIoU": fwiou_avg_summary.get(model, None),
            "std_FWIoU": fwiou_std_summary.get(model, None)
        }
        for model in all_models
    }
}

with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
    json.dump(output_json_data, f, indent=4)
print(f"\nAlle Ergebnisse inkl. Standardabweichung und Durchschnitt wurden in JSON gespeichert: {OUTPUT_JSON}")
# Out:
# === Fold 0: 6 Confusion Matrices gefunden ===
#
# Modell: fcn_resnet101
# Mean IoU: 0.5201
# FWIoU: 0.8013
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9256           32.62
# 1            sidewalk                                     0.6943            5.12
# 2            building                                     0.8120           19.85
# 3            wall                                         0.2391            0.50
# 4            fence                                        0.3728            0.67
# 5            pole                                         0.2202            1.12
# 6            traffic light                                0.3833            0.18
# 7            traffic sign                                 0.5287            0.50
# 8            vegetation                                   0.8465           14.04
# 9            terrain                                      0.5668            0.94
# 10           sky                                          0.8694            3.66
# 11           person                                       0.5979            1.08
# 12           rider                                        0.1978            0.12
# 13           car                                          0.8702            6.41
# 14           truck                                        0.2906            0.30
# 15           bus                                          0.2888            0.28
# 16           train                                        0.2720            0.17
# 17           motorcycle                                   0.3106            0.08
# 18           bicycle                                      0.5283            0.43
# 19           unlabeled                                    0.5865           11.94
#
# Modell: deeplabv3_resnet101
# Mean IoU: 0.5383
# FWIoU: 0.8014
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9129           32.62
# 1            sidewalk                                     0.6888            5.12
# 2            building                                     0.8212           19.85
# 3            wall                                         0.2643            0.50
# 4            fence                                        0.3544            0.67
# 5            pole                                         0.2829            1.12
# 6            traffic light                                0.4061            0.18
# 7            traffic sign                                 0.4949            0.50
# 8            vegetation                                   0.8527           14.04
# 9            terrain                                      0.5836            0.94
# 10           sky                                          0.8635            3.66
# 11           person                                       0.5643            1.08
# 12           rider                                        0.2866            0.12
# 13           car                                          0.8699            6.41
# 14           truck                                        0.3868            0.30
# 15           bus                                          0.3855            0.28
# 16           train                                        0.3258            0.17
# 17           motorcycle                                   0.2926            0.08
# 18           bicycle                                      0.5343            0.43
# 19           unlabeled                                    0.5947           11.94
#
# Modell: deeplabv3_resnet50
# Mean IoU: 0.4599
# FWIoU: 0.7815
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9104           32.62
# 1            sidewalk                                     0.6308            5.12
# 2            building                                     0.8061           19.85
# 3            wall                                         0.3166            0.50
# 4            fence                                        0.3552            0.67
# 5            pole                                         0.2056            1.12
# 6            traffic light                                0.2881            0.18
# 7            traffic sign                                 0.4233            0.50
# 8            vegetation                                   0.8283           14.04
# 9            terrain                                      0.5291            0.94
# 10           sky                                          0.8449            3.66
# 11           person                                       0.5234            1.08
# 12           rider                                        0.0585            0.12
# 13           car                                          0.8326            6.41
# 14           truck                                        0.1685            0.30
# 15           bus                                          0.2909            0.28
# 16           train                                        0.1045            0.17
# 17           motorcycle                                   0.0299            0.08
# 18           bicycle                                      0.4771            0.43
# 19           unlabeled                                    0.5736           11.94
#
# Modell: deeplabv3_mobilenet_v3_large
# Mean IoU: 0.5002
# FWIoU: 0.7821
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9151           32.62
# 1            sidewalk                                     0.6596            5.12
# 2            building                                     0.7995           19.85
# 3            wall                                         0.2615            0.50
# 4            fence                                        0.3751            0.67
# 5            pole                                         0.1369            1.12
# 6            traffic light                                0.2608            0.18
# 7            traffic sign                                 0.3763            0.50
# 8            vegetation                                   0.8182           14.04
# 9            terrain                                      0.5453            0.94
# 10           sky                                          0.8437            3.66
# 11           person                                       0.4903            1.08
# 12           rider                                        0.1893            0.12
# 13           car                                          0.8320            6.41
# 14           truck                                        0.3058            0.30
# 15           bus                                          0.3969            0.28
# 16           train                                        0.4629            0.17
# 17           motorcycle                                   0.2722            0.08
# 18           bicycle                                      0.4874            0.43
# 19           unlabeled                                    0.5750           11.94
#
# Modell: lraspp_mobilenet_v3_large
# Mean IoU: 0.4912
# FWIoU: 0.7806
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9099           32.62
# 1            sidewalk                                     0.6456            5.12
# 2            building                                     0.7983           19.85
# 3            wall                                         0.2531            0.50
# 4            fence                                        0.3249            0.67
# 5            pole                                         0.1827            1.12
# 6            traffic light                                0.2696            0.18
# 7            traffic sign                                 0.4090            0.50
# 8            vegetation                                   0.8255           14.04
# 9            terrain                                      0.4997            0.94
# 10           sky                                          0.8627            3.66
# 11           person                                       0.5038            1.08
# 12           rider                                        0.1704            0.12
# 13           car                                          0.8301            6.41
# 14           truck                                        0.2314            0.30
# 15           bus                                          0.4104            0.28
# 16           train                                        0.4235            0.17
# 17           motorcycle                                   0.2315            0.08
# 18           bicycle                                      0.4683            0.43
# 19           unlabeled                                    0.5740           11.94
#
# Modell: fcn_resnet50
# Mean IoU: 0.5408
# FWIoU: 0.7997
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9149           32.62
# 1            sidewalk                                     0.6755            5.12
# 2            building                                     0.8193           19.85
# 3            wall                                         0.3001            0.50
# 4            fence                                        0.3799            0.67
# 5            pole                                         0.2492            1.12
# 6            traffic light                                0.3988            0.18
# 7            traffic sign                                 0.5436            0.50
# 8            vegetation                                   0.8521           14.04
# 9            terrain                                      0.5451            0.94
# 10           sky                                          0.8756            3.66
# 11           person                                       0.5894            1.08
# 12           rider                                        0.2056            0.12
# 13           car                                          0.8700            6.41
# 14           truck                                        0.2988            0.30
# 15           bus                                          0.4542            0.28
# 16           train                                        0.3319            0.17
# 17           motorcycle                                   0.3704            0.08
# 18           bicycle                                      0.5624            0.43
# 19           unlabeled                                    0.5799           11.94
#
# === Fold 1: 6 Confusion Matrices gefunden ===
#
# Modell: fcn_resnet101
# Mean IoU: 0.5214
# FWIoU: 0.8073
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9233           32.65
# 1            sidewalk                                     0.6934            5.30
# 2            building                                     0.8334           19.73
# 3            wall                                         0.4263            0.65
# 4            fence                                        0.3679            0.76
# 5            pole                                         0.2705            1.10
# 6            traffic light                                0.4340            0.19
# 7            traffic sign                                 0.5290            0.49
# 8            vegetation                                   0.8517           14.92
# 9            terrain                                      0.5566            1.01
# 10           sky                                          0.8804            3.32
# 11           person                                       0.6198            1.17
# 12           rider                                        0.3163            0.13
# 13           car                                          0.8633            5.94
# 14           truck                                        0.2376            0.25
# 15           bus                                          0.2441            0.19
# 16           train                                        0.0020            0.23
# 17           motorcycle                                   0.3289            0.08
# 18           bicycle                                      0.4514            0.38
# 19           unlabeled                                    0.5980           11.50
#
# Modell: deeplabv3_resnet101
# Mean IoU: 0.5138
# FWIoU: 0.7927
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9149           32.65
# 1            sidewalk                                     0.6766            5.30
# 2            building                                     0.8143           19.73
# 3            wall                                         0.3722            0.65
# 4            fence                                        0.2600            0.76
# 5            pole                                         0.2422            1.10
# 6            traffic light                                0.3933            0.19
# 7            traffic sign                                 0.4326            0.49
# 8            vegetation                                   0.8357           14.92
# 9            terrain                                      0.5553            1.01
# 10           sky                                          0.8444            3.32
# 11           person                                       0.5766            1.17
# 12           rider                                        0.2845            0.13
# 13           car                                          0.8495            5.94
# 14           truck                                        0.3746            0.25
# 15           bus                                          0.3251            0.19
# 16           train                                        0.3756            0.23
# 17           motorcycle                                   0.1356            0.08
# 18           bicycle                                      0.4263            0.38
# 19           unlabeled                                    0.5862           11.50
#
# Modell: deeplabv3_resnet50
# Mean IoU: 0.5190
# FWIoU: 0.8059
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9306           32.65
# 1            sidewalk                                     0.6488            5.30
# 2            building                                     0.8254           19.73
# 3            wall                                         0.3274            0.65
# 4            fence                                        0.3023            0.76
# 5            pole                                         0.2669            1.10
# 6            traffic light                                0.4013            0.19
# 7            traffic sign                                 0.5180            0.49
# 8            vegetation                                   0.8545           14.92
# 9            terrain                                      0.5780            1.01
# 10           sky                                          0.8760            3.32
# 11           person                                       0.6081            1.17
# 12           rider                                        0.3042            0.13
# 13           car                                          0.8538            5.94
# 14           truck                                        0.1434            0.25
# 15           bus                                          0.2384            0.19
# 16           train                                        0.3917            0.23
# 17           motorcycle                                   0.2235            0.08
# 18           bicycle                                      0.4814            0.38
# 19           unlabeled                                    0.6061           11.50
#
# Modell: deeplabv3_mobilenet_v3_large
# Mean IoU: 0.4966
# FWIoU: 0.7815
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9182           32.65
# 1            sidewalk                                     0.6492            5.30
# 2            building                                     0.7990           19.73
# 3            wall                                         0.3782            0.65
# 4            fence                                        0.3299            0.76
# 5            pole                                         0.1482            1.10
# 6            traffic light                                0.2596            0.19
# 7            traffic sign                                 0.3825            0.49
# 8            vegetation                                   0.8188           14.92
# 9            terrain                                      0.5038            1.01
# 10           sky                                          0.8352            3.32
# 11           person                                       0.4890            1.17
# 12           rider                                        0.2380            0.13
# 13           car                                          0.8249            5.94
# 14           truck                                        0.2490            0.25
# 15           bus                                          0.2843            0.19
# 16           train                                        0.5696            0.23
# 17           motorcycle                                   0.2661            0.08
# 18           bicycle                                      0.4117            0.38
# 19           unlabeled                                    0.5770           11.50
#
# Modell: lraspp_mobilenet_v3_large
# Mean IoU: 0.4979
# FWIoU: 0.7880
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9207           32.65
# 1            sidewalk                                     0.6571            5.30
# 2            building                                     0.8032           19.73
# 3            wall                                         0.3988            0.65
# 4            fence                                        0.3509            0.76
# 5            pole                                         0.1898            1.10
# 6            traffic light                                0.2983            0.19
# 7            traffic sign                                 0.4078            0.49
# 8            vegetation                                   0.8328           14.92
# 9            terrain                                      0.5577            1.01
# 10           sky                                          0.8619            3.32
# 11           person                                       0.3626            1.17
# 12           rider                                        0.2431            0.13
# 13           car                                          0.8178            5.94
# 14           truck                                        0.2347            0.25
# 15           bus                                          0.3147            0.19
# 16           train                                        0.4061            0.23
# 17           motorcycle                                   0.2774            0.08
# 18           bicycle                                      0.4264            0.38
# 19           unlabeled                                    0.5958           11.50
#
# Modell: fcn_resnet50
# Mean IoU: 0.5501
# FWIoU: 0.8099
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9278           32.65
# 1            sidewalk                                     0.6958            5.30
# 2            building                                     0.8256           19.73
# 3            wall                                         0.3217            0.65
# 4            fence                                        0.3143            0.76
# 5            pole                                         0.2139            1.10
# 6            traffic light                                0.4200            0.19
# 7            traffic sign                                 0.5266            0.49
# 8            vegetation                                   0.8591           14.92
# 9            terrain                                      0.6010            1.01
# 10           sky                                          0.8832            3.32
# 11           person                                       0.6329            1.17
# 12           rider                                        0.3059            0.13
# 13           car                                          0.8703            5.94
# 14           truck                                        0.4058            0.25
# 15           bus                                          0.5058            0.19
# 16           train                                        0.1661            0.23
# 17           motorcycle                                   0.3921            0.08
# 18           bicycle                                      0.5321            0.38
# 19           unlabeled                                    0.6014           11.50
#
# === Fold 2: 6 Confusion Matrices gefunden ===
#
# Modell: fcn_resnet101
# Mean IoU: 0.5173
# FWIoU: 0.7987
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9235           32.23
# 1            sidewalk                                     0.6810            5.57
# 2            building                                     0.8283           20.75
# 3            wall                                         0.2846            0.49
# 4            fence                                        0.2784            0.75
# 5            pole                                         0.2840            1.19
# 6            traffic light                                0.3400            0.19
# 7            traffic sign                                 0.5087            0.50
# 8            vegetation                                   0.8478           13.79
# 9            terrain                                      0.5739            0.96
# 10           sky                                          0.8680            3.46
# 11           person                                       0.5877            1.07
# 12           rider                                        0.2924            0.14
# 13           car                                          0.8473            5.77
# 14           truck                                        0.2466            0.25
# 15           bus                                          0.3495            0.21
# 16           train                                        0.0217            0.22
# 17           motorcycle                                   0.4685            0.09
# 18           bicycle                                      0.5357            0.40
# 19           unlabeled                                    0.5785           11.97
#
# Modell: deeplabv3_resnet101
# Mean IoU: 0.5491
# FWIoU: 0.8016
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9206           32.23
# 1            sidewalk                                     0.6752            5.57
# 2            building                                     0.8304           20.75
# 3            wall                                         0.3216            0.49
# 4            fence                                        0.3464            0.75
# 5            pole                                         0.2795            1.19
# 6            traffic light                                0.4181            0.19
# 7            traffic sign                                 0.4592            0.50
# 8            vegetation                                   0.8493           13.79
# 9            terrain                                      0.5979            0.96
# 10           sky                                          0.8712            3.46
# 11           person                                       0.5796            1.07
# 12           rider                                        0.3368            0.14
# 13           car                                          0.8456            5.77
# 14           truck                                        0.3338            0.25
# 15           bus                                          0.3361            0.21
# 16           train                                        0.4501            0.22
# 17           motorcycle                                   0.4225            0.09
# 18           bicycle                                      0.5158            0.40
# 19           unlabeled                                    0.5928           11.97
#
# Modell: deeplabv3_resnet50
# Mean IoU: 0.5519
# FWIoU: 0.7988
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9155           32.23
# 1            sidewalk                                     0.6670            5.57
# 2            building                                     0.8292           20.75
# 3            wall                                         0.3126            0.49
# 4            fence                                        0.3439            0.75
# 5            pole                                         0.2830            1.19
# 6            traffic light                                0.4018            0.19
# 7            traffic sign                                 0.4917            0.50
# 8            vegetation                                   0.8493           13.79
# 9            terrain                                      0.5722            0.96
# 10           sky                                          0.8695            3.46
# 11           person                                       0.5745            1.07
# 12           rider                                        0.3846            0.14
# 13           car                                          0.8622            5.77
# 14           truck                                        0.2649            0.25
# 15           bus                                          0.3783            0.21
# 16           train                                        0.4637            0.22
# 17           motorcycle                                   0.4746            0.09
# 18           bicycle                                      0.5167            0.40
# 19           unlabeled                                    0.5826           11.97
#
# Modell: deeplabv3_mobilenet_v3_large
# Mean IoU: 0.5176
# FWIoU: 0.7784
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9143           32.23
# 1            sidewalk                                     0.6521            5.57
# 2            building                                     0.8039           20.75
# 3            wall                                         0.2737            0.49
# 4            fence                                        0.3207            0.75
# 5            pole                                         0.1600            1.19
# 6            traffic light                                0.2962            0.19
# 7            traffic sign                                 0.3672            0.50
# 8            vegetation                                   0.8129           13.79
# 9            terrain                                      0.5385            0.96
# 10           sky                                          0.8315            3.46
# 11           person                                       0.4619            1.07
# 12           rider                                        0.2324            0.14
# 13           car                                          0.8168            5.77
# 14           truck                                        0.3747            0.25
# 15           bus                                          0.4065            0.21
# 16           train                                        0.6405            0.22
# 17           motorcycle                                   0.4187            0.09
# 18           bicycle                                      0.4553            0.40
# 19           unlabeled                                    0.5739           11.97
#
# Modell: lraspp_mobilenet_v3_large
# Mean IoU: 0.5102
# FWIoU: 0.7791
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9112           32.23
# 1            sidewalk                                     0.6370            5.57
# 2            building                                     0.8013           20.75
# 3            wall                                         0.3045            0.49
# 4            fence                                        0.2793            0.75
# 5            pole                                         0.1968            1.19
# 6            traffic light                                0.3144            0.19
# 7            traffic sign                                 0.3799            0.50
# 8            vegetation                                   0.8276           13.79
# 9            terrain                                      0.4762            0.96
# 10           sky                                          0.8533            3.46
# 11           person                                       0.4696            1.07
# 12           rider                                        0.2768            0.14
# 13           car                                          0.8321            5.77
# 14           truck                                        0.3001            0.25
# 15           bus                                          0.3224            0.21
# 16           train                                        0.6179            0.22
# 17           motorcycle                                   0.3662            0.09
# 18           bicycle                                      0.4647            0.40
# 19           unlabeled                                    0.5729           11.97
#
# Modell: fcn_resnet50
# Mean IoU: 0.5162
# FWIoU: 0.7973
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9156           32.23
# 1            sidewalk                                     0.6868            5.57
# 2            building                                     0.8316           20.75
# 3            wall                                         0.2313            0.49
# 4            fence                                        0.3091            0.75
# 5            pole                                         0.2816            1.19
# 6            traffic light                                0.4449            0.19
# 7            traffic sign                                 0.5191            0.50
# 8            vegetation                                   0.8487           13.79
# 9            terrain                                      0.5923            0.96
# 10           sky                                          0.8783            3.46
# 11           person                                       0.5945            1.07
# 12           rider                                        0.2653            0.14
# 13           car                                          0.8446            5.77
# 14           truck                                        0.3131            0.25
# 15           bus                                          0.2124            0.21
# 16           train                                        0.0024            0.22
# 17           motorcycle                                   0.4746            0.09
# 18           bicycle                                      0.5019            0.40
# 19           unlabeled                                    0.5759           11.97
#
# === Fold 3: 6 Confusion Matrices gefunden ===
#
# Modell: fcn_resnet101
# Mean IoU: 0.5484
# FWIoU: 0.8140
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9321           32.90
# 1            sidewalk                                     0.6840            5.02
# 2            building                                     0.8269           19.92
# 3            wall                                         0.2461            0.56
# 4            fence                                        0.4182            0.84
# 5            pole                                         0.2749            1.08
# 6            traffic light                                0.4446            0.18
# 7            traffic sign                                 0.5195            0.50
# 8            vegetation                                   0.8594           14.37
# 9            terrain                                      0.5591            1.05
# 10           sky                                          0.8793            3.46
# 11           person                                       0.6138            1.02
# 12           rider                                        0.2822            0.12
# 13           car                                          0.8762            6.26
# 14           truck                                        0.3186            0.23
# 15           bus                                          0.5704            0.23
# 16           train                                        0.0924            0.15
# 17           motorcycle                                   0.3816            0.08
# 18           bicycle                                      0.5783            0.44
# 19           unlabeled                                    0.6110           11.60
#
# Modell: deeplabv3_resnet101
# Mean IoU: 0.5401
# FWIoU: 0.8047
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9187           32.90
# 1            sidewalk                                     0.6513            5.02
# 2            building                                     0.8272           19.92
# 3            wall                                         0.3502            0.56
# 4            fence                                        0.4183            0.84
# 5            pole                                         0.2739            1.08
# 6            traffic light                                0.4003            0.18
# 7            traffic sign                                 0.5145            0.50
# 8            vegetation                                   0.8538           14.37
# 9            terrain                                      0.5395            1.05
# 10           sky                                          0.8726            3.46
# 11           person                                       0.5946            1.02
# 12           rider                                        0.3046            0.12
# 13           car                                          0.8655            6.26
# 14           truck                                        0.2846            0.23
# 15           bus                                          0.5099            0.23
# 16           train                                        0.2220            0.15
# 17           motorcycle                                   0.2373            0.08
# 18           bicycle                                      0.5663            0.44
# 19           unlabeled                                    0.5969           11.60
#
# Modell: deeplabv3_resnet50
# Mean IoU: 0.5330
# FWIoU: 0.8101
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9329           32.90
# 1            sidewalk                                     0.6708            5.02
# 2            building                                     0.8244           19.92
# 3            wall                                         0.3274            0.56
# 4            fence                                        0.4147            0.84
# 5            pole                                         0.2847            1.08
# 6            traffic light                                0.3943            0.18
# 7            traffic sign                                 0.4879            0.50
# 8            vegetation                                   0.8514           14.37
# 9            terrain                                      0.5955            1.05
# 10           sky                                          0.8759            3.46
# 11           person                                       0.5769            1.02
# 12           rider                                        0.2840            0.12
# 13           car                                          0.8551            6.26
# 14           truck                                        0.2656            0.23
# 15           bus                                          0.4265            0.23
# 16           train                                        0.2976            0.15
# 17           motorcycle                                   0.1497            0.08
# 18           bicycle                                      0.5371            0.44
# 19           unlabeled                                    0.6082           11.60
#
# Modell: deeplabv3_mobilenet_v3_large
# Mean IoU: 0.4867
# FWIoU: 0.7811
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9199           32.90
# 1            sidewalk                                     0.6312            5.02
# 2            building                                     0.7961           19.92
# 3            wall                                         0.2710            0.56
# 4            fence                                        0.4154            0.84
# 5            pole                                         0.1604            1.08
# 6            traffic light                                0.2914            0.18
# 7            traffic sign                                 0.3602            0.50
# 8            vegetation                                   0.8237           14.37
# 9            terrain                                      0.5574            1.05
# 10           sky                                          0.8306            3.46
# 11           person                                       0.4634            1.02
# 12           rider                                        0.1516            0.12
# 13           car                                          0.7972            6.26
# 14           truck                                        0.3003            0.23
# 15           bus                                          0.3382            0.23
# 16           train                                        0.3458            0.15
# 17           motorcycle                                   0.1924            0.08
# 18           bicycle                                      0.5104            0.44
# 19           unlabeled                                    0.5774           11.60
#
# Modell: lraspp_mobilenet_v3_large
# Mean IoU: 0.4941
# FWIoU: 0.7877
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9168           32.90
# 1            sidewalk                                     0.6430            5.02
# 2            building                                     0.8050           19.92
# 3            wall                                         0.2932            0.56
# 4            fence                                        0.4072            0.84
# 5            pole                                         0.2054            1.08
# 6            traffic light                                0.3248            0.18
# 7            traffic sign                                 0.3841            0.50
# 8            vegetation                                   0.8360           14.37
# 9            terrain                                      0.5686            1.05
# 10           sky                                          0.8592            3.46
# 11           person                                       0.4749            1.02
# 12           rider                                        0.1745            0.12
# 13           car                                          0.8327            6.26
# 14           truck                                        0.1775            0.23
# 15           bus                                          0.3129            0.23
# 16           train                                        0.3818            0.15
# 17           motorcycle                                   0.1961            0.08
# 18           bicycle                                      0.5144            0.44
# 19           unlabeled                                    0.5738           11.60
#
# Modell: fcn_resnet50
# Mean IoU: 0.5174
# FWIoU: 0.8039
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9286           32.90
# 1            sidewalk                                     0.6853            5.02
# 2            building                                     0.8184           19.92
# 3            wall                                         0.2822            0.56
# 4            fence                                        0.3808            0.84
# 5            pole                                         0.2306            1.08
# 6            traffic light                                0.4355            0.18
# 7            traffic sign                                 0.5145            0.50
# 8            vegetation                                   0.8463           14.37
# 9            terrain                                      0.5511            1.05
# 10           sky                                          0.8451            3.46
# 11           person                                       0.6016            1.02
# 12           rider                                        0.3032            0.12
# 13           car                                          0.8603            6.26
# 14           truck                                        0.1219            0.23
# 15           bus                                          0.4055            0.23
# 16           train                                        0.0749            0.15
# 17           motorcycle                                   0.2986            0.08
# 18           bicycle                                      0.5664            0.44
# 19           unlabeled                                    0.5979           11.60
#
# === Fold 4: 6 Confusion Matrices gefunden ===
#
# Modell: fcn_resnet101
# Mean IoU: 0.5340
# FWIoU: 0.8095
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9379           33.00
# 1            sidewalk                                     0.6930            5.42
# 2            building                                     0.8218           19.97
# 3            wall                                         0.3316            0.74
# 4            fence                                        0.2882            0.82
# 5            pole                                         0.2686            1.09
# 6            traffic light                                0.4217            0.17
# 7            traffic sign                                 0.5069            0.52
# 8            vegetation                                   0.8506           14.11
# 9            terrain                                      0.4984            0.95
# 10           sky                                          0.8752            3.44
# 11           person                                       0.4917            1.09
# 12           rider                                        0.2549            0.14
# 13           car                                          0.8698            6.21
# 14           truck                                        0.4991            0.18
# 15           bus                                          0.4468            0.22
# 16           train                                        0.1611            0.19
# 17           motorcycle                                   0.3750            0.09
# 18           bicycle                                      0.4827            0.36
# 19           unlabeled                                    0.6050           11.28
#
# Modell: deeplabv3_resnet101
# Mean IoU: 0.5591
# FWIoU: 0.8172
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9365           33.00
# 1            sidewalk                                     0.6947            5.42
# 2            building                                     0.8292           19.97
# 3            wall                                         0.3858            0.74
# 4            fence                                        0.4067            0.82
# 5            pole                                         0.2987            1.09
# 6            traffic light                                0.3950            0.17
# 7            traffic sign                                 0.5256            0.52
# 8            vegetation                                   0.8506           14.11
# 9            terrain                                      0.5266            0.95
# 10           sky                                          0.8805            3.44
# 11           person                                       0.6100            1.09
# 12           rider                                        0.3810            0.14
# 13           car                                          0.8780            6.21
# 14           truck                                        0.3418            0.18
# 15           bus                                          0.3397            0.22
# 16           train                                        0.4958            0.19
# 17           motorcycle                                   0.3133            0.09
# 18           bicycle                                      0.4654            0.36
# 19           unlabeled                                    0.6263           11.28
#
# Modell: deeplabv3_resnet50
# Mean IoU: 0.5468
# FWIoU: 0.8166
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9402           33.00
# 1            sidewalk                                     0.7124            5.42
# 2            building                                     0.8208           19.97
# 3            wall                                         0.3560            0.74
# 4            fence                                        0.3921            0.82
# 5            pole                                         0.2827            1.09
# 6            traffic light                                0.3789            0.17
# 7            traffic sign                                 0.5241            0.52
# 8            vegetation                                   0.8447           14.11
# 9            terrain                                      0.5207            0.95
# 10           sky                                          0.8783            3.44
# 11           person                                       0.6053            1.09
# 12           rider                                        0.3607            0.14
# 13           car                                          0.8746            6.21
# 14           truck                                        0.4420            0.18
# 15           bus                                          0.3599            0.22
# 16           train                                        0.4059            0.19
# 17           motorcycle                                   0.1511            0.09
# 18           bicycle                                      0.4511            0.36
# 19           unlabeled                                    0.6344           11.28
#
# Modell: deeplabv3_mobilenet_v3_large
# Mean IoU: 0.4883
# FWIoU: 0.7832
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9194           33.00
# 1            sidewalk                                     0.6336            5.42
# 2            building                                     0.7972           19.97
# 3            wall                                         0.4106            0.74
# 4            fence                                        0.3776            0.82
# 5            pole                                         0.1115            1.09
# 6            traffic light                                0.2632            0.17
# 7            traffic sign                                 0.3717            0.52
# 8            vegetation                                   0.8144           14.11
# 9            terrain                                      0.4833            0.95
# 10           sky                                          0.8290            3.44
# 11           person                                       0.4873            1.09
# 12           rider                                        0.1917            0.14
# 13           car                                          0.8368            6.21
# 14           truck                                        0.3199            0.18
# 15           bus                                          0.4214            0.22
# 16           train                                        0.2347            0.19
# 17           motorcycle                                   0.2269            0.09
# 18           bicycle                                      0.4405            0.36
# 19           unlabeled                                    0.5950           11.28
#
# Modell: lraspp_mobilenet_v3_large
# Mean IoU: 0.5069
# FWIoU: 0.7897
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9235           33.00
# 1            sidewalk                                     0.6553            5.42
# 2            building                                     0.7996           19.97
# 3            wall                                         0.3474            0.74
# 4            fence                                        0.3540            0.82
# 5            pole                                         0.1664            1.09
# 6            traffic light                                0.2858            0.17
# 7            traffic sign                                 0.3792            0.52
# 8            vegetation                                   0.8293           14.11
# 9            terrain                                      0.5039            0.95
# 10           sky                                          0.8577            3.44
# 11           person                                       0.4887            1.09
# 12           rider                                        0.2160            0.14
# 13           car                                          0.8407            6.21
# 14           truck                                        0.3292            0.18
# 15           bus                                          0.4303            0.22
# 16           train                                        0.4115            0.19
# 17           motorcycle                                   0.2747            0.09
# 18           bicycle                                      0.4537            0.36
# 19           unlabeled                                    0.5901           11.28
#
# Modell: fcn_resnet50
# Mean IoU: 0.5205
# FWIoU: 0.8050
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            road                                         0.9277           33.00
# 1            sidewalk                                     0.6844            5.42
# 2            building                                     0.8202           19.97
# 3            wall                                         0.1867            0.74
# 4            fence                                        0.2399            0.82
# 5            pole                                         0.2867            1.09
# 6            traffic light                                0.4010            0.17
# 7            traffic sign                                 0.5465            0.52
# 8            vegetation                                   0.8509           14.11
# 9            terrain                                      0.5288            0.95
# 10           sky                                          0.8708            3.44
# 11           person                                       0.6116            1.09
# 12           rider                                        0.3718            0.14
# 13           car                                          0.8594            6.21
# 14           truck                                        0.4026            0.18
# 15           bus                                          0.3369            0.22
# 16           train                                        0.1172            0.19
# 17           motorcycle                                   0.2491            0.09
# 18           bicycle                                      0.5105            0.36
# 19           unlabeled                                    0.6080           11.28
#
# Alle Ergebnisse inkl. Standardabweichung und Durchschnitt wurden in JSON gespeichert: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/evaluation_results_k_fold.json

# %%
# Sammle alle Modelle, die in irgendeinem Fold vorkommen
all_models = set()
for fold_name in results_summary:
    for model_name in results_summary[fold_name]:
        all_models.add(model_name)

# Für jedes gefundene Modell wird nun eine Tabelle ausgegeben
for model_name in sorted(all_models):
    # Sammle pro Fold die iou_per_class, frequency_percent, mIoU und FWIoU
    fold_data = {}
    miou_list = []
    fwiou_list = []
    for fold_name in results_summary:
        if model_name in results_summary[fold_name]:
            iou_list = results_summary[fold_name][model_name]["iou_per_class"]
            freq_list = results_summary[fold_name][model_name]["frequency_percent"]
            miou = results_summary[fold_name][model_name]["mIoU"]
            fwiou = results_summary[fold_name][model_name]["FWIoU"]
            fold_data[fold_name] = (iou_list, freq_list)
            miou_list.append(miou)
            fwiou_list.append(fwiou)
        else:
            fold_data[fold_name] = (None, None)
    
    # Berechne Standardabweichung für mIoU und FWIoU über alle Folds
    miou_std = np.std(miou_list) if miou_list else None
    fwiou_std = np.std(fwiou_list) if fwiou_list else None

    # Kopfzeile
    print(f"\n{'='*70}")
    print(f"Modell: {model_name}")
    print(f"{'='*70}")
    if miou_std is not None and fwiou_std is not None:
        print(f"mIoU_std: {miou_std:.4f}   FWIoU_std: {fwiou_std:.4f}")
    else:
        print("mIoU_std: -   FWIoU_std: -")
    
    # Baue eine Kopfzeile mit den Spalten: Class_ID, Class_Name, dann je Fold -> IoU, Freq
    header = f"{'Class_ID':<10} {'Class_Name':<25}"
    sorted_folds = sorted(fold_data.keys())  # z.B. Fold0, Fold1, ...
    for fold_name in sorted_folds:
        header += f"{fold_name}_IoU   {fold_name}_Freq   "
    print(header)
    print("-"*70)

    # Zeilen pro Klasse
    for cls_idx in range(NUM_CLASSES):
        class_name = city_classes.get(cls_idx, f"Class {cls_idx}")
        row_str = f"{cls_idx:<10} {class_name:<25}"

        # Für jeden Fold die IoU und Frequency einfügen
        for fold_name in sorted_folds:
            iou_freq = fold_data[fold_name]
            if iou_freq[0] is not None:
                iou_val = iou_freq[0][cls_idx]
                freq_val = iou_freq[1][cls_idx]
                row_str += f"{iou_val:>9.4f} {freq_val:>12.2f}   "
            else:
                row_str += f"{'-':>9} {'-':>12}   "

        print(row_str)
# Out:
# ======================================================================
# Modell: deeplabv3_mobilenet_v3_large
# ======================================================================
# mIoU_std: 0.0111   FWIoU_std: 0.0016
# Class_ID   Class_Name               Fold0_IoU   Fold0_Freq   Fold1_IoU   Fold1_Freq   Fold2_IoU   Fold2_Freq   Fold3_IoU   Fold3_Freq   Fold4_IoU   Fold4_Freq
# ----------------------------------------------------------------------
# 0          road                        0.9151        32.62      0.9182        32.65      0.9143        32.23      0.9199        32.90      0.9194        33.00
# 1          sidewalk                    0.6596         5.12      0.6492         5.30      0.6521         5.57      0.6312         5.02      0.6336         5.42
# 2          building                    0.7995        19.85      0.7990        19.73      0.8039        20.75      0.7961        19.92      0.7972        19.97
# 3          wall                        0.2615         0.50      0.3782         0.65      0.2737         0.49      0.2710         0.56      0.4106         0.74
# 4          fence                       0.3751         0.67      0.3299         0.76      0.3207         0.75      0.4154         0.84      0.3776         0.82
# 5          pole                        0.1369         1.12      0.1482         1.10      0.1600         1.19      0.1604         1.08      0.1115         1.09
# 6          traffic light               0.2608         0.18      0.2596         0.19      0.2962         0.19      0.2914         0.18      0.2632         0.17
# 7          traffic sign                0.3763         0.50      0.3825         0.49      0.3672         0.50      0.3602         0.50      0.3717         0.52
# 8          vegetation                  0.8182        14.04      0.8188        14.92      0.8129        13.79      0.8237        14.37      0.8144        14.11
# 9          terrain                     0.5453         0.94      0.5038         1.01      0.5385         0.96      0.5574         1.05      0.4833         0.95
# 10         sky                         0.8437         3.66      0.8352         3.32      0.8315         3.46      0.8306         3.46      0.8290         3.44
# 11         person                      0.4903         1.08      0.4890         1.17      0.4619         1.07      0.4634         1.02      0.4873         1.09
# 15         bus                         0.4542         0.28      0.5058         0.19      0.2124         0.21      0.4055         0.23      0.3369         0.22
# 16         train                       0.3319         0.17      0.1661         0.23      0.0024         0.22      0.0749         0.15      0.1172         0.19
# 17         motorcycle                  0.3704         0.08      0.3921         0.08      0.4746         0.09      0.2986         0.08      0.2491         0.09
# 18         bicycle                     0.5624         0.43      0.5321         0.38      0.5019         0.40      0.5664         0.44      0.5105         0.36
# 19         unlabeled                   0.5799        11.94      0.6014        11.50      0.5759        11.97      0.5979        11.60      0.6080        11.28
#
# ======================================================================
# Modell: lraspp_mobilenet_v3_large
# ======================================================================
# mIoU_std: 0.0073   FWIoU_std: 0.0043
# Class_ID   Class_Name               Fold0_IoU   Fold0_Freq   Fold1_IoU   Fold1_Freq   Fold2_IoU   Fold2_Freq   Fold3_IoU   Fold3_Freq   Fold4_IoU   Fold4_Freq
# ----------------------------------------------------------------------
# 0          road                        0.9099        32.62      0.9207        32.65      0.9112        32.23      0.9168        32.90      0.9235        33.00
# 1          sidewalk                    0.6456         5.12      0.6571         5.30      0.6370         5.57      0.6430         5.02      0.6553         5.42
# 2          building                    0.7983        19.85      0.8032        19.73      0.8013        20.75      0.8050        19.92      0.7996        19.97
# 3          wall                        0.2531         0.50      0.3988         0.65      0.3045         0.49      0.2932         0.56      0.3474         0.74
# 4          fence                       0.3249         0.67      0.3509         0.76      0.2793         0.75      0.4072         0.84      0.3540         0.82
# 5          pole                        0.1827         1.12      0.1898         1.10      0.1968         1.19      0.2054         1.08      0.1664         1.09
# 6          traffic light               0.2696         0.18      0.2983         0.19      0.3144         0.19      0.3248         0.18      0.2858         0.17
# 7          traffic sign                0.4090         0.50      0.4078         0.49      0.3799         0.50      0.3841         0.50      0.3792         0.52
# 8          vegetation                  0.8255        14.04      0.8328        14.92      0.8276        13.79      0.8360        14.37      0.8293        14.11
# 9          terrain                     0.4997         0.94      0.5577         1.01      0.4762         0.96      0.5686         1.05      0.5039         0.95
# 10         sky                         0.8627         3.66      0.8619         3.32      0.8533         3.46      0.8592         3.46      0.8577         3.44
# 11         person                      0.5038         1.08      0.3626         1.17      0.4696         1.07      0.4749         1.02      0.4887         1.09
# 12         rider                       0.1704         0.12      0.2431         0.13      0.2768         0.14      0.1745         0.12      0.2160         0.14
# 13         car                         0.8301         6.41      0.8178         5.94      0.8321         5.77      0.8327         6.26      0.8407         6.21
# 14         truck                       0.2314         0.30      0.2347         0.25      0.3001         0.25      0.1775         0.23      0.3292         0.18
# 15         bus                         0.4104         0.28      0.3147         0.19      0.3224         0.21      0.3129         0.23      0.4303         0.22
# 16         train                       0.4235         0.17      0.4061         0.23      0.6179         0.22      0.3818         0.15      0.4115         0.19
# 17         motorcycle                  0.2315         0.08      0.2774         0.08      0.3662         0.09      0.1961         0.08      0.2747         0.09
# 18         bicycle                     0.4683         0.43      0.4264         0.38      0.4647         0.40      0.5144         0.44      0.4537         0.36
# 19         unlabeled                   0.5740        11.94      0.5958        11.50      0.5729        11.97      0.5738        11.60      0.5901        11.28
