# %%
# Step 1: Verify TensorRT and PyCUDA installation
try:
    import tensorrt as trt
    import pycuda.driver as cuda
    import pycuda.autoinit
    print("TensorRT and PyCUDA are installed.")
except ImportError as e:
    print("TensorRT and/or PyCUDA are not installed. Please install them before proceeding.")
    raise e

import os
import numpy as np
from Helper.calibrator import * 
import glob
# Out:
# TensorRT and PyCUDA are installed.

# %%
from Helper.onnx_konv import ONNXModelConverter

checkpoint_path = "/home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/hyper_city/deeplabv3_resnet101_best_checkpoint.pkl"  
export_dir = "./onnx_models2"  # <-- Update this if desired!

model_name = "deeplabv3_resnet101"

# Create the converter object with the specified parameters
converter = ONNXModelConverter(
    checkpoint_path=checkpoint_path,
    model_name=model_name,
    width=2048,
    height=1024,
    input_shape=(1, 3, 520, 520),
    dynamic_batch=True,
    opset_version=13,
    output_dir=export_dir,
    skip_local_load=True
)

print("[DEBUG] Loading model from checkpoint...")
converter.load_model()
print("[DEBUG] Model loaded successfully.")

print("[DEBUG] Exporting FP32 ONNX model...")
fp32_onnx_path = converter.export_fp32()
print("FP32 ONNX model exported at:", fp32_onnx_path)
# Out:
# Initialisierung abgeschlossen. Gerät: cuda. Ausgabeordner: ./onnx_models2
# [DEBUG] Loading model from checkpoint...
# 2025-02-10 14:45:56.195995: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 14:45:56.753011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using CUDA GPU
# Model loaded: deeplabv3_resnet101 | Device: cuda
# Skipping local .pth load logic (likely using external Ray checkpoint).
# Modell deeplabv3_resnet101 erfolgreich geladen und auf cuda platziert.
# [DEBUG] Model loaded successfully.
# [DEBUG] Exporting FP32 ONNX model...
# FP32 ONNX-Modell exportiert: ./onnx_models2/deeplabv3_resnet101_fp32.onnx
# FP32 ONNX model exported at: ./onnx_models2/deeplabv3_resnet101_fp32.onnx

# %%
run = False
calibration_data_path = "/home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images" 
input_tensor_name = "input"

print("[DEBUG] Converting FP32 ONNX model to INT8 calibrated ONNX model...")
if run: 
    int8_calibrated_onnx_path = converter.quantize_int8_calibrated(
        fp32_onnx_path=fp32_onnx_path,
        calibration_data_path=calibration_data_path,
        input_tensor_name=input_tensor_name,
        max_samples=100
    )
    print("INT8 calibrated ONNX model exported at:", int8_calibrated_onnx_path)
# Out:
# [DEBUG] Converting FP32 ONNX model to INT8 calibrated ONNX model...

# %%
import os

# Update this path to your calibration images directory.
calibration_image_dir = "/home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images"

# Gather all calibration image paths (adjust the file extensions as needed)
calibration_image_paths = [
    os.path.join(calibration_image_dir, f)
    for f in os.listdir(calibration_image_dir)
    if f.lower().endswith((".png", ".jpg", ".jpeg"))
]

print(f"Found {len(calibration_image_paths)} calibration images.")

# Set batch size, input shape, and max_samples.
batch_size = 8
input_shape = (3, 520, 520)  # (C, H, W)
max_samples = 100
cache_file = "calibration.cache"

# Instantiate the calibrator.
calibrator = MyCalibrator(
    calibration_image_paths=calibration_image_paths,
    batch_size=batch_size,
    input_shape=input_shape,
    max_samples=max_samples,
    cache_file=cache_file
)
print("Calibrator instantiated successfully.")
# Out:
# Found 3475 calibration images.
# [DEBUG] Processed calibration image 1/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001593_01.png
# [DEBUG] Processed calibration image 2/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000997_01.png
# [DEBUG] Processed calibration image 3/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001056_01.png
# [DEBUG] Processed calibration image 4/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003355_01.png
# [DEBUG] Processed calibration image 5/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002130_01.png
# [DEBUG] Processed calibration image 6/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000171_01.png
# [DEBUG] Processed calibration image 7/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001787_01.png
# [DEBUG] Processed calibration image 8/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002053_01.png
# [DEBUG] Processed calibration image 9/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000600_01.png
# [DEBUG] Processed calibration image 10/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003354_01.png
# [DEBUG] Processed calibration image 11/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002909_01.png
# [DEBUG] Processed calibration image 12/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000845_01.png
# [DEBUG] Processed calibration image 13/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000964_01.png
# [DEBUG] Processed calibration image 14/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001746_01.png
# [DEBUG] Processed calibration image 15/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003446_01.png
# [DEBUG] Processed calibration image 16/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000329_01.png
# [DEBUG] Processed calibration image 17/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001932_01.png
# [DEBUG] Processed calibration image 18/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003384_01.png
# [DEBUG] Processed calibration image 19/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001698_01.png
# [DEBUG] Processed calibration image 20/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001980_01.png
# [DEBUG] Processed calibration image 21/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001025_01.png
# [DEBUG] Processed calibration image 22/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000713_01.png
# [DEBUG] Processed calibration image 23/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002484_01.png
# [DEBUG] Processed calibration image 24/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001266_01.png
# [DEBUG] Processed calibration image 25/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000436_01.png
# [DEBUG] Processed calibration image 26/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001548_01.png
# [DEBUG] Processed calibration image 27/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000250_01.png
# [DEBUG] Processed calibration image 28/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002703_01.png
# [DEBUG] Processed calibration image 29/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000677_01.png
# [DEBUG] Processed calibration image 30/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001338_01.png
# [DEBUG] Processed calibration image 31/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001826_01.png
# [DEBUG] Processed calibration image 32/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000503_01.png
# [DEBUG] Processed calibration image 33/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001389_01.png
# [DEBUG] Processed calibration image 34/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001936_01.png
# [DEBUG] Processed calibration image 35/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001796_01.png
# [DEBUG] Processed calibration image 36/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003140_01.png
# [DEBUG] Processed calibration image 37/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000550_01.png
# [DEBUG] Processed calibration image 38/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003053_01.png
# [DEBUG] Processed calibration image 39/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001317_01.png
# [DEBUG] Processed calibration image 40/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001275_01.png
# [DEBUG] Processed calibration image 41/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002839_01.png
# [DEBUG] Processed calibration image 42/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002952_01.png
# [DEBUG] Processed calibration image 43/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002530_01.png
# [DEBUG] Processed calibration image 44/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003219_01.png
# [DEBUG] Processed calibration image 45/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002906_01.png
# [DEBUG] Processed calibration image 46/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002612_01.png
# [DEBUG] Processed calibration image 47/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000931_01.png
# [DEBUG] Processed calibration image 48/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001213_01.png
# [DEBUG] Processed calibration image 49/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000281_01.png
# [DEBUG] Processed calibration image 50/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003422_01.png
# [DEBUG] Processed calibration image 51/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000918_01.png
# [DEBUG] Processed calibration image 52/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000996_01.png
# [DEBUG] Processed calibration image 53/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001097_01.png
# [DEBUG] Processed calibration image 54/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001912_01.png
# [DEBUG] Processed calibration image 55/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002342_01.png
# [DEBUG] Processed calibration image 56/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001665_01.png
# [DEBUG] Processed calibration image 57/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002505_01.png
# [DEBUG] Processed calibration image 58/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001196_01.png
# [DEBUG] Processed calibration image 59/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003252_01.png
# [DEBUG] Processed calibration image 60/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002778_01.png
# [DEBUG] Processed calibration image 61/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002991_01.png
# [DEBUG] Processed calibration image 62/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001904_01.png
# [DEBUG] Processed calibration image 63/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000546_01.png
# [DEBUG] Processed calibration image 64/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003268_01.png
# [DEBUG] Processed calibration image 65/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001829_01.png
# [DEBUG] Processed calibration image 66/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002533_01.png
# [DEBUG] Processed calibration image 67/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001101_01.png
# [DEBUG] Processed calibration image 68/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003211_01.png
# [DEBUG] Processed calibration image 69/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002775_01.png
# [DEBUG] Processed calibration image 70/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000588_01.png
# [DEBUG] Processed calibration image 71/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000834_01.png
# [DEBUG] Processed calibration image 72/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001505_01.png
# [DEBUG] Processed calibration image 73/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000510_01.png
# [DEBUG] Processed calibration image 74/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002162_01.png
# [DEBUG] Processed calibration image 75/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000227_01.png
# [DEBUG] Processed calibration image 76/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002632_01.png
# [DEBUG] Processed calibration image 77/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001151_01.png
# [DEBUG] Processed calibration image 78/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000946_01.png
# [DEBUG] Processed calibration image 79/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001258_01.png
# [DEBUG] Processed calibration image 80/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000322_01.png
# [DEBUG] Processed calibration image 81/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001887_01.png
# [DEBUG] Processed calibration image 82/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000492_01.png
# [DEBUG] Processed calibration image 83/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/00000983_01.png
# [DEBUG] Processed calibration image 84/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001563_01.png
# [DEBUG] Processed calibration image 85/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002356_01.png
# [DEBUG] Processed calibration image 86/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002428_01.png
# [DEBUG] Processed calibration image 87/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003150_01.png
# [DEBUG] Processed calibration image 88/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000003241_01.png
# [DEBUG] Processed calibration image 89/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001286_01.png
# [DEBUG] Processed calibration image 90/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002385_01.png
# [DEBUG] Processed calibration image 91/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001606_01.png
# [DEBUG] Processed calibration image 92/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001084_01.png
# [DEBUG] Processed calibration image 93/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001626_01.png
# [DEBUG] Processed calibration image 94/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001199_01.png
# [DEBUG] Processed calibration image 95/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001729_01.png
# [DEBUG] Processed calibration image 96/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001969_01.png
# [DEBUG] Processed calibration image 97/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001013_01.png
# [DEBUG] Processed calibration image 98/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000002003_01.png
# [DEBUG] Processed calibration image 99/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001031_01.png
# [DEBUG] Processed calibration image 100/100: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/CityscapesDaten/images/000001071_01.png
# Calibrator instantiated successfully.

# %%
TRT_LOGGER = trt.Logger(trt.Logger.WARNING)

def build_engine(onnx_file_path, engine_file_path, calibrator=None):
    """
    Build a TensorRT engine from an ONNX file.
    
    Parameters:
      - onnx_file_path: Path to the INT8-calibrated ONNX model.
      - engine_file_path: Where to save the resulting engine file.
      - calibrator: An instance of your custom calibrator (for INT8 mode), or None.
      
    Returns:
      - The path to the saved engine file, or None if engine build failed.
    """
    # Use explicit batch mode by setting the appropriate flag.
    explicit_batch = 1 << int(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)
    
    # Create the builder, network, builder config, and ONNX parser.
    with trt.Builder(TRT_LOGGER) as builder, \
         builder.create_network(explicit_batch) as network, \
         builder.create_builder_config() as config, \
         trt.OnnxParser(network, TRT_LOGGER) as parser:

        # Set the maximum workspace size (e.g., 1GB) using the new API:
        config.set_memory_pool_limit(trt.MemoryPoolType.WORKSPACE, 1 << 30)  # 1GB

        # If a calibrator is provided, enable INT8 mode.
        if calibrator is not None:
            print("[DEBUG] Enabling INT8 mode with calibrator...")
            config.set_flag(trt.BuilderFlag.INT8)
            config.int8_calibrator = calibrator

        # Parse the ONNX model.
        with open(onnx_file_path, 'rb') as model_file:
            print(f"[DEBUG] Parsing ONNX model from: {onnx_file_path}")
            if not parser.parse(model_file.read()):
                print("Failed to parse the ONNX model. Errors:")
                for error in range(parser.num_errors):
                    print(parser.get_error(error))
                return None

        print("[DEBUG] Successfully parsed ONNX model. Building engine...")
        engine = builder.build_engine(network, config)
        if engine is None:
            print("Engine build failed!")
            return None

        # Serialize and save the engine.
        with open(engine_file_path, 'wb') as f:
            f.write(engine.serialize())
        print("[DEBUG] Engine built and saved successfully!")
        return engine_file_path

# Example usage:
onnx_int8_calibrated_onnx_path = "./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed.onnx"
engine_output_path = "./engine_files/deeplabv3_resnet101_int8_calibrated.engine"
os.makedirs(os.path.dirname(engine_output_path), exist_ok=True)
engine_file = build_engine(onnx_int8_calibrated_onnx_path, engine_output_path, calibrator=calibrator)
print("TensorRT engine file exported at:", engine_file)
# Out:
# [DEBUG] Enabling INT8 mode with calibrator...
# [DEBUG] Parsing ONNX model from: ./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed.onnx
# [02/10/2025-14:50:07] [TRT] [E] In node 15 with name: input_QuantizeLinear and operator: QuantizeLinear (QuantDequantLinearHelper): INVALID_NODE: Assertion failed: shiftIsAllZeros(zeroPoint): TensorRT only supports symmetric quantization. The zero point for the QuantizeLinear/DequantizeLinear operator must be all zeros.Failed to parse the ONNX model. Errors:
# In node 15 with name: input_QuantizeLinear and operator: QuantizeLinear (QuantDequantLinearHelper): INVALID_NODE: Assertion failed: shiftIsAllZeros(zeroPoint): TensorRT only supports symmetric quantization. The zero point for the QuantizeLinear/DequantizeLinear operator must be all zeros.
#
# TensorRT engine file exported at: None
# /tmp/ipykernel_14438/2630228858.py:31: DeprecationWarning: Use Deprecated in TensorRT 10.1. Superseded by explicit quantization. instead.
#   config.int8_calibrator = calibrator

# %%
import onnx
from onnx import helper

# Load your ONNX model.
model_path = "./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed.onnx"
model = onnx.load(model_path)

# Loop through nodes and look for DequantizeLinear nodes.
print("Listing all DequantizeLinear nodes and their attributes:")
for node in model.graph.node:
    if node.op_type == "DequantizeLinear":
        print(f"\nNode name: {node.name}")
        for attr in node.attribute:
            value = helper.get_attribute_value(attr)
            print(f"  {attr.name}: {value}")

# Specifically inspect the node "classifier.4.bias_DequantizeLinear"
for node in model.graph.node:
    if node.name == "classifier.4.bias_DequantizeLinear":
        print("\n*** Offending Node Found ***")
        print(helper.printable_graph(onnx.helper.make_graph([node], "temp_graph", [], [])))
# Out:
# Listing all DequantizeLinear nodes and their attributes:
#
# Node name: classifier.4.weight_DequantizeLinear
#
# Node name: onnx::Conv_1078_DequantizeLinear
#
# Node name: onnx::Conv_1079_DequantizeLinear
#
# Node name: onnx::Conv_1081_DequantizeLinear
#
# Node name: onnx::Conv_1082_DequantizeLinear
#
# Node name: onnx::Conv_1084_DequantizeLinear
#
# Node name: onnx::Conv_1085_DequantizeLinear
#
# Node name: onnx::Conv_1087_DequantizeLinear
#
# Node name: onnx::Conv_1088_DequantizeLinear
#
# Node name: onnx::Conv_1090_DequantizeLinear
#
# Node name: onnx::Conv_1091_DequantizeLinear
#
# Node name: onnx::Conv_1093_DequantizeLinear
#
# Node name: onnx::Conv_1094_DequantizeLinear
#
# Node name: onnx::Conv_1096_DequantizeLinear
#
# Node name: onnx::Conv_1097_DequantizeLinear
#
# Node name: onnx::Conv_1099_DequantizeLinear
#
# Node name: onnx::Conv_1100_DequantizeLinear
#
# Node name: onnx::Conv_1102_DequantizeLinear
#
# Node name: onnx::Conv_1103_DequantizeLinear
#
# Node name: onnx::Conv_1105_DequantizeLinear
#
# Node name: onnx::Conv_1106_DequantizeLinear
#
# Node name: onnx::Conv_1108_DequantizeLinear
#
# Node name: onnx::Conv_1109_DequantizeLinear
#
# Node name: onnx::Conv_1111_DequantizeLinear
#
# Node name: onnx::Conv_1112_DequantizeLinear
#
# Node name: onnx::Conv_1114_DequantizeLinear
#
# Node name: onnx::Conv_1115_DequantizeLinear
#
# Node name: onnx::Conv_1117_DequantizeLinear
#
# Node name: onnx::Conv_1118_DequantizeLinear
#
# Node name: onnx::Conv_1120_DequantizeLinear
#
# Node name: onnx::Conv_1121_DequantizeLinear
#
# Node name: onnx::Conv_1123_DequantizeLinear
#
# Node name: onnx::Conv_1124_DequantizeLinear
#
# Node name: onnx::Conv_1126_DequantizeLinear
#
# Node name: onnx::Conv_1127_DequantizeLinear
#
# Node name: onnx::Conv_1129_DequantizeLinear
#
# Node name: onnx::Conv_1130_DequantizeLinear
#
# Node name: onnx::Conv_1132_DequantizeLinear
#
# Node name: onnx::Conv_1133_DequantizeLinear
#
# Node name: onnx::Conv_1135_DequantizeLinear
#
# Node name: onnx::Conv_1136_DequantizeLinear
#
# Node name: onnx::Conv_1138_DequantizeLinear
#
# Node name: onnx::Conv_1139_DequantizeLinear
#
# Node name: onnx::Conv_1141_DequantizeLinear
#
# Node name: onnx::Conv_1142_DequantizeLinear
#
# Node name: onnx::Conv_1144_DequantizeLinear
#
# Node name: onnx::Conv_1145_DequantizeLinear
#
# Node name: onnx::Conv_1147_DequantizeLinear
#
# Node name: onnx::Conv_1148_DequantizeLinear
#
# Node name: onnx::Conv_1150_DequantizeLinear
#
# Node name: onnx::Conv_1151_DequantizeLinear
#
# Node name: onnx::Conv_1153_DequantizeLinear
#
# Node name: onnx::Conv_1154_DequantizeLinear
#
# Node name: onnx::Conv_1156_DequantizeLinear
#
# Node name: onnx::Conv_1157_DequantizeLinear
#
# Node name: onnx::Conv_1159_DequantizeLinear
#
# Node name: onnx::Conv_1160_DequantizeLinear
#
# Node name: onnx::Conv_1162_DequantizeLinear
#
# Node name: onnx::Conv_1163_DequantizeLinear
#
# Node name: onnx::Conv_1165_DequantizeLinear
#
# Node name: onnx::Conv_1166_DequantizeLinear
#
# Node name: onnx::Conv_1168_DequantizeLinear
#
# Node name: onnx::Conv_1169_DequantizeLinear
#
# Node name: onnx::Conv_1171_DequantizeLinear
#
# Node name: onnx::Conv_1172_DequantizeLinear
#
# Node name: onnx::Conv_1174_DequantizeLinear
#
# Node name: onnx::Conv_1175_DequantizeLinear
#
# Node name: onnx::Conv_1177_DequantizeLinear
#
# Node name: onnx::Conv_1178_DequantizeLinear
#
# Node name: onnx::Conv_1180_DequantizeLinear
#
# Node name: onnx::Conv_1181_DequantizeLinear
#
# Node name: onnx::Conv_1183_DequantizeLinear
#
# Node name: onnx::Conv_1184_DequantizeLinear
#
# Node name: onnx::Conv_1186_DequantizeLinear
#
# Node name: onnx::Conv_1187_DequantizeLinear
#
# Node name: onnx::Conv_1189_DequantizeLinear
#
# Node name: onnx::Conv_1190_DequantizeLinear
#
# Node name: onnx::Conv_1192_DequantizeLinear
#
# Node name: onnx::Conv_1193_DequantizeLinear
#
# Node name: onnx::Conv_1195_DequantizeLinear
#
# Node name: onnx::Conv_1196_DequantizeLinear
#
# Node name: onnx::Conv_1198_DequantizeLinear
#
# Node name: onnx::Conv_1199_DequantizeLinear
#
# Node name: onnx::Conv_1201_DequantizeLinear
#
# Node name: onnx::Conv_1202_DequantizeLinear
#
# Node name: onnx::Conv_1204_DequantizeLinear
#
# Node name: onnx::Conv_1205_DequantizeLinear
#
# Node name: onnx::Conv_1207_DequantizeLinear
#
# Node name: onnx::Conv_1208_DequantizeLinear
#
# Node name: onnx::Conv_1210_DequantizeLinear
#
# Node name: onnx::Conv_1211_DequantizeLinear
#
# Node name: onnx::Conv_1213_DequantizeLinear
#
# Node name: onnx::Conv_1214_DequantizeLinear
#
# Node name: onnx::Conv_1216_DequantizeLinear
#
# Node name: onnx::Conv_1217_DequantizeLinear
#
# Node name: onnx::Conv_1219_DequantizeLinear
#
# Node name: onnx::Conv_1220_DequantizeLinear
#
# Node name: onnx::Conv_1222_DequantizeLinear
#
# Node name: onnx::Conv_1223_DequantizeLinear
#
# Node name: onnx::Conv_1225_DequantizeLinear
#
# Node name: onnx::Conv_1226_DequantizeLinear
#
# Node name: onnx::Conv_1228_DequantizeLinear
#
# Node name: onnx::Conv_1229_DequantizeLinear
#
# Node name: onnx::Conv_1231_DequantizeLinear
#
# Node name: onnx::Conv_1232_DequantizeLinear
#
# Node name: onnx::Conv_1234_DequantizeLinear
#
# Node name: onnx::Conv_1235_DequantizeLinear
#
# Node name: onnx::Conv_1237_DequantizeLinear
#
# Node name: onnx::Conv_1238_DequantizeLinear
#
# Node name: onnx::Conv_1240_DequantizeLinear
#
# Node name: onnx::Conv_1241_DequantizeLinear
#
# Node name: onnx::Conv_1243_DequantizeLinear
#
# Node name: onnx::Conv_1244_DequantizeLinear
#
# Node name: onnx::Conv_1246_DequantizeLinear
#
# Node name: onnx::Conv_1247_DequantizeLinear
#
# Node name: onnx::Conv_1249_DequantizeLinear
#
# Node name: onnx::Conv_1250_DequantizeLinear
#
# Node name: onnx::Conv_1252_DequantizeLinear
#
# Node name: onnx::Conv_1253_DequantizeLinear
#
# Node name: onnx::Conv_1255_DequantizeLinear
#
# Node name: onnx::Conv_1256_DequantizeLinear
#
# Node name: onnx::Conv_1258_DequantizeLinear
#
# Node name: onnx::Conv_1259_DequantizeLinear
#
# Node name: onnx::Conv_1261_DequantizeLinear
#
# Node name: onnx::Conv_1262_DequantizeLinear
#
# Node name: onnx::Conv_1264_DequantizeLinear
#
# Node name: onnx::Conv_1265_DequantizeLinear
#
# Node name: onnx::Conv_1267_DequantizeLinear
#
# Node name: onnx::Conv_1268_DequantizeLinear
#
# Node name: onnx::Conv_1270_DequantizeLinear
#
# Node name: onnx::Conv_1271_DequantizeLinear
#
# Node name: onnx::Conv_1273_DequantizeLinear
#
# Node name: onnx::Conv_1274_DequantizeLinear
#
# Node name: onnx::Conv_1276_DequantizeLinear
#
# Node name: onnx::Conv_1277_DequantizeLinear
#
# Node name: onnx::Conv_1279_DequantizeLinear
#
# Node name: onnx::Conv_1280_DequantizeLinear
#
# Node name: onnx::Conv_1282_DequantizeLinear
#
# Node name: onnx::Conv_1283_DequantizeLinear
#
# Node name: onnx::Conv_1285_DequantizeLinear
#
# Node name: onnx::Conv_1286_DequantizeLinear
#
# Node name: onnx::Conv_1288_DequantizeLinear
#
# Node name: onnx::Conv_1289_DequantizeLinear
#
# Node name: onnx::Conv_1291_DequantizeLinear
#
# Node name: onnx::Conv_1292_DequantizeLinear
#
# Node name: onnx::Conv_1294_DequantizeLinear
#
# Node name: onnx::Conv_1295_DequantizeLinear
#
# Node name: onnx::Conv_1297_DequantizeLinear
#
# Node name: onnx::Conv_1298_DequantizeLinear
#
# Node name: onnx::Conv_1300_DequantizeLinear
#
# Node name: onnx::Conv_1301_DequantizeLinear
#
# Node name: onnx::Conv_1303_DequantizeLinear
#
# Node name: onnx::Conv_1304_DequantizeLinear
#
# Node name: onnx::Conv_1306_DequantizeLinear
#
# Node name: onnx::Conv_1307_DequantizeLinear
#
# Node name: onnx::Conv_1309_DequantizeLinear
#
# Node name: onnx::Conv_1310_DequantizeLinear
#
# Node name: onnx::Conv_1312_DequantizeLinear
#
# Node name: onnx::Conv_1313_DequantizeLinear
#
# Node name: onnx::Conv_1315_DequantizeLinear
#
# Node name: onnx::Conv_1316_DequantizeLinear
#
# Node name: onnx::Conv_1318_DequantizeLinear
#
# Node name: onnx::Conv_1319_DequantizeLinear
#
# Node name: onnx::Conv_1321_DequantizeLinear
#
# Node name: onnx::Conv_1322_DequantizeLinear
#
# Node name: onnx::Conv_1324_DequantizeLinear
#
# Node name: onnx::Conv_1325_DequantizeLinear
#
# Node name: onnx::Conv_1327_DequantizeLinear
#
# Node name: onnx::Conv_1328_DequantizeLinear
#
# Node name: onnx::Conv_1330_DequantizeLinear
#
# Node name: onnx::Conv_1331_DequantizeLinear
#
# Node name: onnx::Conv_1333_DequantizeLinear
#
# Node name: onnx::Conv_1334_DequantizeLinear
#
# Node name: onnx::Conv_1336_DequantizeLinear
#
# Node name: onnx::Conv_1337_DequantizeLinear
#
# Node name: onnx::Conv_1339_DequantizeLinear
#
# Node name: onnx::Conv_1340_DequantizeLinear
#
# Node name: onnx::Conv_1342_DequantizeLinear
#
# Node name: onnx::Conv_1343_DequantizeLinear
#
# Node name: onnx::Conv_1345_DequantizeLinear
#
# Node name: onnx::Conv_1346_DequantizeLinear
#
# Node name: onnx::Conv_1348_DequantizeLinear
#
# Node name: onnx::Conv_1349_DequantizeLinear
#
# Node name: onnx::Conv_1351_DequantizeLinear
#
# Node name: onnx::Conv_1352_DequantizeLinear
#
# Node name: onnx::Conv_1354_DequantizeLinear
#
# Node name: onnx::Conv_1355_DequantizeLinear
#
# Node name: onnx::Conv_1357_DequantizeLinear
#
# Node name: onnx::Conv_1358_DequantizeLinear
#
# Node name: onnx::Conv_1360_DequantizeLinear
#
# Node name: onnx::Conv_1361_DequantizeLinear
#
# Node name: onnx::Conv_1363_DequantizeLinear
#
# Node name: onnx::Conv_1364_DequantizeLinear
#
# Node name: onnx::Conv_1366_DequantizeLinear
#
# Node name: onnx::Conv_1367_DequantizeLinear
#
# Node name: onnx::Conv_1369_DequantizeLinear
#
# Node name: onnx::Conv_1370_DequantizeLinear
#
# Node name: onnx::Conv_1372_DequantizeLinear
#
# Node name: onnx::Conv_1373_DequantizeLinear
#
# Node name: onnx::Conv_1375_DequantizeLinear
#
# Node name: onnx::Conv_1376_DequantizeLinear
#
# Node name: onnx::Conv_1378_DequantizeLinear
#
# Node name: onnx::Conv_1379_DequantizeLinear
#
# Node name: onnx::Conv_1381_DequantizeLinear
#
# Node name: onnx::Conv_1382_DequantizeLinear
#
# Node name: onnx::Conv_1384_DequantizeLinear
#
# Node name: onnx::Conv_1385_DequantizeLinear
#
# Node name: onnx::Conv_1387_DequantizeLinear
#
# Node name: onnx::Conv_1388_DequantizeLinear
#
# Node name: onnx::Conv_1390_DequantizeLinear
#
# Node name: onnx::Conv_1391_DequantizeLinear
#
# Node name: onnx::Conv_1393_DequantizeLinear
#
# Node name: onnx::Conv_1394_DequantizeLinear
#
# Node name: onnx::Conv_1396_DequantizeLinear
#
# Node name: onnx::Conv_1397_DequantizeLinear
#
# Node name: onnx::Conv_1399_DequantizeLinear
#
# Node name: onnx::Conv_1400_DequantizeLinear
#
# Node name: onnx::Conv_1402_DequantizeLinear
#
# Node name: onnx::Conv_1403_DequantizeLinear
#
# Node name: onnx::Conv_1405_DequantizeLinear
#
# Node name: onnx::Conv_1406_DequantizeLinear
#
# Node name: onnx::Conv_1408_DequantizeLinear
#
# Node name: onnx::Conv_1409_DequantizeLinear
#
# Node name: input_DequantizeLinear
#
# Node name: /backbone/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/maxpool/MaxPool_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.0/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.0/downsample/downsample.0/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.0/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.0/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.0/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.1/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.1/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.1/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.1/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.2/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.2/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.2/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer1/layer1.2/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.0/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.0/downsample/downsample.0/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.0/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.0/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.0/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.1/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.1/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.1/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.1/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.2/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.2/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.2/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.2/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.3/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.3/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.3/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer2/layer2.3/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.0/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.0/downsample/downsample.0/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.0/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.0/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.0/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.1/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.1/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.1/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.1/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.2/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.2/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.2/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.2/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.3/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.3/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.3/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.3/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.4/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.4/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.4/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.4/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.5/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.5/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.5/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.5/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.6/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.6/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.6/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.6/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.7/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.7/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.7/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.7/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.8/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.8/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.8/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.8/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.9/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.9/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.9/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.9/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.10/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.10/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.10/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.10/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.11/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.11/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.11/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.11/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.12/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.12/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.12/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.12/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.13/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.13/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.13/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.13/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.14/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.14/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.14/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.14/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.15/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.15/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.15/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.15/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.16/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.16/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.16/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.16/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.17/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.17/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.17/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.17/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.18/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.18/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.18/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.18/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.19/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.19/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.19/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.19/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.20/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.20/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.20/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.20/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.21/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.21/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.21/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.21/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.22/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.22/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.22/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer3/layer3.22/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.0/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.0/downsample/downsample.0/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.0/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.0/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.0/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.1/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.1/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.1/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.1/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.2/relu/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.2/relu_1/Relu_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.2/conv3/Conv_output_0_DequantizeLinear
#
# Node name: /backbone/layer4/layer4.2/relu_2/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/convs.0/convs.0.2/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/convs.1/convs.1.2/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/convs.2/convs.2.2/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/convs.3/convs.3.2/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/convs.4/convs.4.0/GlobalAveragePool_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/convs.4/convs.4.3/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/convs.4/Resize_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/Concat_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.0/project/project.2/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.3/Relu_output_0_DequantizeLinear
#
# Node name: /classifier/classifier.4/Conv_output_0_DequantizeLinear
#
# Node name: output_DequantizeLinear

# %%
import onnx
import numpy as np
from onnx import numpy_helper

# Update this path to your ONNX model.
model_path = "./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated.onnx"
fixed_model_path = "./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed.onnx"

# Load the ONNX model.
model = onnx.load(model_path)
graph = model.graph

def find_initializer(name):
    for init in graph.initializer:
        if init.name == name:
            return numpy_helper.to_array(init)
    return None

# Locate the offending dequantize node.
offending_node = None
for node in graph.node:
    if node.op_type == "DequantizeLinear" and node.name == "classifier.4.bias_DequantizeLinear":
        offending_node = node
        break

if offending_node is None:
    print("Offending node 'classifier.4.bias_DequantizeLinear' not found.")
else:
    print("Offending node found:")
    print(offending_node)
    
    # The dequantize node should have three inputs:
    #   input[0]: quantized bias (e.g., int8 array)
    #   input[1]: scale (float)
    #   input[2]: zero point (int8 or uint8)
    quant_bias = find_initializer(offending_node.input[0])
    scale = find_initializer(offending_node.input[1])
    zero_point = find_initializer(offending_node.input[2])
    
    if quant_bias is None or scale is None or zero_point is None:
        print("Could not locate one or more of the required initializers.")
    else:
        print("Quantized bias shape:", quant_bias.shape)
        print("Scale:", scale)
        print("Zero point:", zero_point)
        
        # Compute the dequantized bias.
        dequant_bias = (quant_bias.astype(np.float32) - zero_point.astype(np.float32)) * scale.astype(np.float32)
        print("Dequantized bias computed, shape:", dequant_bias.shape)
        
        # Create a new initializer for the dequantized bias.
        new_bias_initializer = numpy_helper.from_array(dequant_bias, name=offending_node.output[0])
        
        # Add the new initializer to the graph.
        graph.initializer.append(new_bias_initializer)
        
        # Remove the offending dequantize node from the graph.
        graph.node.remove(offending_node)
        print("Offending DequantizeLinear node removed.")
        
        # Save the fixed model.
        onnx.save(model, fixed_model_path)
        print(f"Fixed model saved at: {fixed_model_path}")
# Out:
# Offending node found:
# input: "classifier.4.bias_quantized"
# input: "classifier.4.bias_quantized_scale"
# input: "classifier.4.bias_quantized_zero_point"
# output: "classifier.4.bias"
# name: "classifier.4.bias_DequantizeLinear"
# op_type: "DequantizeLinear"
#
# Quantized bias shape: (20,)
# Scale: [7.932402e-05]
# Zero point: 0
# Dequantized bias computed, shape: (20,)
# Offending DequantizeLinear node removed.
# Fixed model saved at: ./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed.onnx

# %%
import onnx
import numpy as np
from onnx import numpy_helper

# Path to your previously fixed ONNX model.
model_path = "./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed.onnx"
# Save the new modified model to a new file.
fixed2_model_path = "./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed2.onnx"

# Load the model.
model = onnx.load(model_path)
graph = model.graph

# Find the QuantizeLinear node for the input (by name "input_QuantizeLinear")
quantize_node = None
for node in graph.node:
    if node.op_type == "QuantizeLinear" and node.name == "input_QuantizeLinear":
        quantize_node = node
        break

if quantize_node is None:
    print("Node 'input_QuantizeLinear' not found in the model.")
else:
    print("Found node 'input_QuantizeLinear':")
    print(quantize_node)
    
    # The QuantizeLinear node is expected to have three inputs:
    # [0]: the input tensor, [1]: scale, [2]: zero point.
    # We need to set the zero point (input index 2) to all zeros.
    zp_name = quantize_node.input[2]
    
    # Find the initializer corresponding to the zero point.
    zp_initializer = None
    for init in graph.initializer:
        if init.name == zp_name:
            zp_initializer = init
            break
    
    if zp_initializer is None:
        print(f"No initializer found for zero point '{zp_name}'.")
    else:
        # Convert the initializer to a NumPy array.
        original_zp = numpy_helper.to_array(zp_initializer)
        print("Original zero point value:", original_zp)
        
        # Create a new zero point array with the same shape and type but filled with zeros.
        new_zp = np.zeros_like(original_zp)
        print("New zero point value (all zeros):", new_zp)
        
        # Create a new initializer from the new zero point.
        new_zp_initializer = numpy_helper.from_array(new_zp, name=zp_name)
        
        # Replace the old initializer with the new one.
        graph.initializer.remove(zp_initializer)
        graph.initializer.append(new_zp_initializer)
        print("Zero point initializer updated successfully.")
        
        # Save the modified model.
        onnx.save(model, fixed2_model_path)
        print("Modified ONNX model saved to:", fixed2_model_path)
# Out:
# Found node 'input_QuantizeLinear':
# input: "input"
# input: "input_scale"
# input: "input_zero_point"
# output: "input_QuantizeLinear_Output"
# name: "input_QuantizeLinear"
# op_type: "QuantizeLinear"
#
# Original zero point value: -128
# New zero point value (all zeros): 0
# Zero point initializer updated successfully.
# Modified ONNX model saved to: ./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed2.onnx

# %%
import tensorrt as trt
import os

TRT_LOGGER = trt.Logger(trt.Logger.WARNING)

def build_engine(onnx_file_path, engine_file_path, calibrator=None):
    """
    Build a TensorRT engine from an ONNX file.

    Parameters:
      - onnx_file_path: Path to the INT8-calibrated ONNX model.
      - engine_file_path: Where to save the resulting engine file.
      - calibrator: An instance of your custom calibrator (for INT8 mode), or None.

    Returns:
      - The path to the saved engine file, or None if engine build failed.
    """
    # Use explicit batch mode flag.
    explicit_batch = 1 << int(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)

    # Create builder, network, config, and ONNX parser.
    with trt.Builder(TRT_LOGGER) as builder, \
         builder.create_network(explicit_batch) as network, \
         builder.create_builder_config() as config, \
         trt.OnnxParser(network, TRT_LOGGER) as parser:

        # Set the maximum workspace size using the builder config API.
        config.set_memory_pool_limit(trt.MemoryPoolType.WORKSPACE, 1 << 30)  # 1GB

        # If a calibrator is provided, enable INT8 mode.
        if calibrator is not None:
            print("[DEBUG] Enabling INT8 mode with calibrator...")
            config.set_flag(trt.BuilderFlag.INT8)
            config.int8_calibrator = calibrator

        # Parse the ONNX model.
        with open(onnx_file_path, 'rb') as model_file:
            print(f"[DEBUG] Parsing ONNX model from: {onnx_file_path}")
            if not parser.parse(model_file.read()):
                print("Failed to parse the ONNX model. Errors:")
                for error in range(parser.num_errors):
                    print(parser.get_error(error))
                return None

        print("[DEBUG] Successfully parsed ONNX model. Building engine...")
        engine = builder.build_engine(network, config)
        if engine is None:
            print("[ERROR] Engine build failed!")
            return None

        # Serialize and save the engine.
        with open(engine_file_path, 'wb') as f:
            f.write(engine.serialize())
        print("[DEBUG] Engine built and saved successfully to:", engine_file_path)
        return engine_file_path

# Update these paths as needed.
onnx_int8_calibrated_onnx_path = "./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed2.onnx"  # Make sure this is the fixed ONNX model
engine_output_path = "./engine_files/deeplabv3_resnet101_int8_calibrated.engine"
os.makedirs(os.path.dirname(engine_output_path), exist_ok=True)

print("[DEBUG] Building TensorRT engine from ONNX file...")
engine_file = build_engine(onnx_int8_calibrated_onnx_path, engine_output_path, calibrator=calibrator)
print("TensorRT engine file exported at:", engine_file)
# Out:
# [DEBUG] Building TensorRT engine from ONNX file...
# [DEBUG] Enabling INT8 mode with calibrator...
# [DEBUG] Parsing ONNX model from: ./onnx_models/deeplabv3_resnet101_fp32_int8_calibrated_fixed2.onnx
# [02/10/2025-14:51:57] [TRT] [W] onnxOpImporters.cpp:1499: TensorRT doesn't support QuantizeLinear/DequantizeLinear with UINT8 zero_point. TensorRT will use INT8 instead.
# [02/10/2025-14:51:57] [TRT] [E] IDequantizeLayer::setPrecision: Error Code 3: API Usage Error (Parameter check failed, condition: isQuantized(dataType). A DequantizeLayer can only run in DataType::kINT8, DataType::kFP8, DataType::kFP4 or DataType::kINT4precision)
# [02/10/2025-14:51:57] [TRT] [E] ITensor::getDimensions: Error Code 3: API Usage Error (onnx::Conv_1079_DequantizeLinear: only activation types allowed as input to this layer.)
# Failed to parse the ONNX model. Errors:
# In node 17 with name: onnx::Conv_1079_DequantizeLinear and operator: DequantizeLinear (parseNode): INVALID_NODE: Invalid Node - onnx::Conv_1079_DequantizeLinear
# IDequantizeLayer::setPrecision: Error Code 3: API Usage Error (Parameter check failed, condition: isQuantized(dataType). A DequantizeLayer can only run in DataType::kINT8, DataType::kFP8, DataType::kFP4 or DataType::kINT4precision)
# ITensor::getDimensions: Error Code 3: API Usage Error (onnx::Conv_1079_DequantizeLinear: only activation types allowed as input to this layer.)
# [02/10/2025-14:51:57] [TRT] [E] In node 17 with name: onnx::Conv_1079_DequantizeLinear and operator: DequantizeLinear (parseNode): INVALID_NODE: Invalid Node - onnx::Conv_1079_DequantizeLinear
# IDequantizeLayer::setPrecision: Error Code 3: API Usage Error (Parameter check failed, condition: isQuantized(dataType). A DequantizeLayer can only run in DataType::kINT8, DataType::kFP8, DataType::kFP4 or DataType::kINT4precision)
# ITensor::getDimensions: Error Code 3: API Usage Error (onnx::Conv_1079_DequantizeLinear: only activation types allowed as input to this layer.)
# /tmp/ipykernel_14438/1487771513.py:34: DeprecationWarning: Use Deprecated in TensorRT 10.1. Superseded by explicit quantization. instead.
#   config.int8_calibrator = calibrator
# TensorRT engine file exported at: None
