# %%
import os
import json
import pandas as pd
import torch
import numpy as np
from tqdm import tqdm
import glob

# %%
BASE_PATH = "/home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation"
CONF_MATRIX_DIR = os.path.join(BASE_PATH, "FINAL_DATEN/confusion_matrices_hyper_small")
EVAL_RESULTS_SAVE_PATH = os.path.join(BASE_PATH, "FINAL_DATEN", "evaluation_results_map_small.json")

# Debug-Ausgabe der gesetzten Pfade:
print("BASE_PATH:", BASE_PATH)
print("CONF_MATRIX_DIR:", CONF_MATRIX_DIR)
print("Evaluation Results Save Path:", EVAL_RESULTS_SAVE_PATH)
# Out:
# BASE_PATH: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation
# CONF_MATRIX_DIR: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/confusion_matrices_hyper_small
# Evaluation Results Save Path: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/evaluation_results_map_small.json

# %%
def compute_confusion_matrix_metrics(cm):
    """
    Berechnet mIoU und FWIoU für eine gegebene Confusion Matrix.
    Rückgabe: Dictionary mit mIoU und FWIoU.
    """
    # Intersection, Ground Truth und Predicted Summe
    intersection = torch.diag(cm)
    ground_truth_set = cm.sum(1)
    predicted_set = cm.sum(0)
    
    # Berechne die IoU für jede Klasse
    union = ground_truth_set + predicted_set - intersection
    IoU = intersection / (union + 1e-6)
    mIoU = torch.mean(IoU).item()
    
    # Berechnung des Frequency Weighted IoU (FWIoU)
    total_pixels_all = cm.sum()
    FWIoU = (ground_truth_set * IoU).sum() / (total_pixels_all + 1e-6)
    FWIoU = FWIoU.item()
    
    return {
        "mIoU": mIoU,
        "FWIoU": FWIoU
    }

# Suche nach allen Confusion Matrix-Dateien im definierten Ordner
conf_files = glob.glob(os.path.join(CONF_MATRIX_DIR, "*_confusion_matrix.pt"))
metrics_summary = {}

for file_path in conf_files:
    model_name = os.path.basename(file_path).split("_confusion_matrix.pt")[0]
    cm = torch.load(file_path)
    metrics = compute_confusion_matrix_metrics(cm)
    metrics_summary[model_name] = metrics
    print(f"Model: {model_name}, mIoU: {metrics['mIoU']:.4f}, FWIoU: {metrics['FWIoU']:.4f}")

# Speichern der Metriken als JSON-Datei
with open(EVAL_RESULTS_SAVE_PATH, "w", encoding="utf-8") as f:
    json.dump(metrics_summary, f, indent=4)

print(f"Evaluation metrics saved to: {EVAL_RESULTS_SAVE_PATH}")
# Out:
# Model: fcn_resnet101, mIoU: 0.1541, FWIoU: 0.8020
# Model: deeplabv3_resnet101, mIoU: 0.1527, FWIoU: 0.8085
# Model: deeplabv3_resnet50, mIoU: 0.1465, FWIoU: 0.8030
# Model: fcn_resnet50, mIoU: 0.1510, FWIoU: 0.7959
# Evaluation metrics saved to: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/evaluation_results_map_small.json

# %%
def compute_confusion_matrix_metrics_ignore_empty(cm):
    """
    Berechnet mIoU und FWIoU für eine gegebene Confusion Matrix,
    wobei Klassen, die im Ground Truth nicht vorkommen (leere Klassen),
    ignoriert werden.
    
    Rückgabe: Dictionary mit mIoU und FWIoU.
    """
    # Berechne Intersection, Ground Truth- und Predicted-Summen (als float)
    intersection = torch.diag(cm)
    ground_truth_set = cm.sum(1).float()
    predicted_set = cm.sum(0).float()
    
    # Berechne die Union und per-Klassen IoU
    union = ground_truth_set + predicted_set - intersection.float()
    IoU = intersection.float() / (union + 1e-6)
    
    # Maske für Klassen, die im Ground Truth vorhanden sind (also nicht leer)
    valid_mask = ground_truth_set > 0

    # Berechne mIoU nur für die validen Klassen
    if valid_mask.sum() > 0:
        mIoU = torch.mean(IoU[valid_mask]).item()
    else:
        mIoU = 0.0

    # Berechne FWIoU basierend auf den validen Klassen
    total_valid_pixels = ground_truth_set[valid_mask].sum() + 1e-6
    FWIoU = (ground_truth_set[valid_mask] * IoU[valid_mask]).sum() / total_valid_pixels
    FWIoU = FWIoU.item()
    
    return {"mIoU": mIoU, "FWIoU": FWIoU}

# Suche nach allen Confusion Matrix-Dateien im definierten Ordner
conf_files = glob.glob(os.path.join(CONF_MATRIX_DIR, "*_confusion_matrix.pt"))
metrics_summary_corrected = {}

for file_path in conf_files:
    model_name = os.path.basename(file_path).split("_confusion_matrix.pt")[0]
    cm = torch.load(file_path)
    metrics = compute_confusion_matrix_metrics_ignore_empty(cm)
    metrics_summary_corrected[model_name] = metrics
    print(f"Model: {model_name}, Corrected Metrics: mIoU = {metrics['mIoU']:.4f}, FWIoU = {metrics['FWIoU']:.4f}")

# Erstelle den Pfad für die korrigierte JSON-Datei, basierend auf EVAL_RESULTS_SAVE_PATH
corrected_path = EVAL_RESULTS_SAVE_PATH.replace(".json", "_corrected.json")
with open(corrected_path, "w", encoding="utf-8") as f:
    json.dump(metrics_summary_corrected, f, indent=4)

print(f"Corrected evaluation metrics saved to: {corrected_path}")
# Out:
# Model: fcn_resnet101, Corrected Metrics: mIoU = 0.2895, FWIoU = 0.8020
# Model: deeplabv3_resnet101, Corrected Metrics: mIoU = 0.2868, FWIoU = 0.8085
# Model: deeplabv3_resnet50, Corrected Metrics: mIoU = 0.2752, FWIoU = 0.8030
# Model: fcn_resnet50, Corrected Metrics: mIoU = 0.2837, FWIoU = 0.7959
# Corrected evaluation metrics saved to: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/evaluation_results_map_small_corrected.json

# %%
# %% Cell 6: Display IoU per Class with Class Names, Frequency and Save to JSON

# Parameter: Ausgabe-Pfad für die JSON-Datei
OUTPUT_JSON_PATH = os.path.join(BASE_PATH, "FINAL_DATEN", "iou_per_class_results_map_small.json")

# Lade die Konfigurationsdatei, um die Klassennamen zu erhalten
config_path = os.path.join(BASE_PATH, "Mapillary_Vistas", "config_v2.0.json")
with open(config_path, "r") as f:
    config = json.load(f)

# Erstelle ein Dictionary, das jedem Index den lesbaren Namen zuordnet
class_names = {i: info["readable"] for i, info in enumerate(config["labels"])}

def compute_iou_and_frequency(cm):
    """
    Berechnet die IoU pro Klasse sowie die relative Häufigkeit (Frequency) 
    basierend auf der Anzahl der Ground Truth-Pixel (in Prozent).
    
    Rückgabe:
        iou_per_class (Tensor): IoU pro Klasse.
        frequency (Tensor): Frequenz jeder Klasse in Prozent.
    """
    epsilon = 1e-6
    intersection = torch.diag(cm).float()
    row_sum = cm.sum(1).float()   # Ground Truth-Pixel pro Klasse
    col_sum = cm.sum(0).float()   # Vorhergesagte Pixel pro Klasse
    union = row_sum + col_sum - intersection + epsilon
    iou_per_class = intersection / union
    
    total_pixels = cm.sum().float() + epsilon
    frequency = (row_sum / total_pixels) * 100.0  # in Prozent
    return iou_per_class, frequency

# Suche nach allen Confusion Matrix-Dateien im definierten Ordner
conf_files = glob.glob(os.path.join(CONF_MATRIX_DIR, "*_confusion_matrix.pt"))

results_dict = {}
NUM_CLASSES = cm.shape[0]


# Ausgabe pro Modell
for file_path in conf_files:
    model_name = os.path.basename(file_path).split("_confusion_matrix.pt")[0]
    cm = torch.load(file_path)
    iou_values, freq_values = compute_iou_and_frequency(cm)
    
    # Erstelle eine Liste mit per-Klassen Metriken
    per_class_metrics = []
    for i in range(NUM_CLASSES):
        name = class_names.get(i, f"Class {i}")
        per_class_metrics.append({
            "class_index": i,
            "class_name": name,
            "IoU": round(iou_values[i].item(), 4),
            "frequency_percent": round(freq_values[i].item(), 2)
        })
    
    # Speichere zusätzlich Mean IoU und FWIoU (über compute_confusion_matrix_metrics oder compute_confusion_matrix_metrics_ignore_empty)
    metrics = compute_confusion_matrix_metrics(cm)
    
    results_dict[model_name] = {
        "mIoU": round(metrics["mIoU"], 4),
        "FWIoU": round(metrics["FWIoU"], 4),
        "per_class": per_class_metrics
    }
    
    # Optionale Konsolenausgabe
    print("=" * 70)
    print(f"Model: {model_name}")
    print(f"Mean IoU: {metrics['mIoU']:.4f}")
    print(f"FWIoU: {metrics['FWIoU']:.4f}")
    print("\nPer-Klassen Metriken:")
    print("{:<12} {:<40} {:>10} {:>15}".format("Class Index", "Class Name", "IoU", "Frequency (%)"))
    print("-" * 70)
    for entry in per_class_metrics:
        print("{:<12} {:<40} {:>10.4f} {:>15.2f}".format(
            entry["class_index"], entry["class_name"], entry["IoU"], entry["frequency_percent"]
        ))
    print("\n")

# Speichern der Ergebnisse als JSON
OUTPUT_JSON_PATH = os.path.join(BASE_PATH, "FINAL_DATEN", "iou_per_class_results_map_small.json")
with open(OUTPUT_JSON_PATH, "w", encoding="utf-8") as f:
    json.dump(results_dict, f, indent=4)
print(f"Ergebnisse wurden in JSON gespeichert: {OUTPUT_JSON_PATH}")
# Out:
# ======================================================================
# Model: fcn_resnet101
# Mean IoU: 0.1541
# FWIoU: 0.8020
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            Bird                                         0.0000            0.00
# 1            Ground Animal                                0.0000            0.00
# 2            Ambiguous Barrier                            0.0000            0.00
# 3            Concrete Block                               0.5939            0.31
# 4            Curb                                         0.4815            0.85
# 5            Fence                                        0.4607            1.27
# 6            Guard Rail                                   0.5903            0.24
# 7            Barrier                                      0.0000            0.00
# 8            Road Median                                  0.0000            0.00
# 9            Road Side                                    0.0000            0.00
# 10           Lane Separator                               0.0000            0.00
# 11           Temporary Barrier                            0.2102            0.02
# 12           Wall                                         0.4018            0.90
# 13           Bike Lane                                    0.2257            0.38
# 14           Crosswalk - Plain                            0.1798            0.25
# 15           Curb Cut                                     0.0804            0.09
# 16           Driveway                                     0.0879            0.16
# 17           Parking                                      0.0000            0.00
# 18           Parking Aisle                                0.0000            0.00
# 19           Pedestrian Area                              0.0850            0.57
# 20           Rail Track                                   0.0000            0.00
# 21           Road                                         0.8417           18.63
# 22           Road Shoulder                                0.2010            0.12
# 23           Service Lane                                 0.0000            0.00
# 24           Sidewalk                                     0.5729            3.15
# 25           Traffic Island                               0.2560            0.31
# 26           Bridge                                       0.0000            0.00
# 27           Building                                     0.8178           12.08
# 28           Garage                                       0.0000            0.00
# 29           Tunnel                                       0.0000            0.00
# 30           Person                                       0.5465            0.31
# 31           Person Group                                 0.0239            0.02
# 32           Bicyclist                                    0.3118            0.03
# 33           Motorcyclist                                 0.2978            0.02
# 34           Other Rider                                  0.0000            0.00
# 35           Lane Marking - Dashed Line                   0.3334            0.28
# 36           Lane Marking - Straight Line                 0.5093            0.52
# 37           Lane Marking - Zigzag Line                   0.0000            0.00
# 38           Lane Marking - Ambiguous                     0.0000            0.01
# 39           Lane Marking - Arrow (Left)                  0.1317            0.01
# 40           Lane Marking - Arrow (Other)                 0.0995            0.01
# 41           Lane Marking - Arrow (Right)                 0.0154            0.01
# 42           Lane Marking - Arrow (Split Left or Straight)     0.0000            0.01
# 43           Lane Marking - Arrow (Split Right or Straight)     0.0641            0.01
# 44           Lane Marking - Arrow (Straight)              0.3063            0.02
# 45           Lane Marking - Crosswalk                     0.6698            0.79
# 46           Lane Marking - Give Way (Row)                0.0000            0.01
# 47           Lane Marking - Give Way (Single)             0.0000            0.00
# 48           Lane Marking - Hatched (Chevron)             0.0970            0.04
# 49           Lane Marking - Hatched (Diagonal)            0.3620            0.12
# 50           Lane Marking - Other                         0.2252            0.13
# 51           Lane Marking - Stop Line                     0.3015            0.08
# 52           Lane Marking - Symbol (Bicycle)              0.4023            0.02
# 53           Lane Marking - Symbol (Other)                0.0000            0.02
# 54           Lane Marking - Text                          0.4061            0.08
# 55           Lane Marking (only) - Dashed Line            0.0000            0.00
# 56           Lane Marking (only) - Crosswalk              0.0000            0.00
# 57           Lane Marking (only) - Other                  0.0000            0.00
# 58           Lane Marking (only) - Test                   0.0000            0.00
# 59           Mountain                                     0.0000            0.00
# 60           Sand                                         0.0000            0.00
# 61           Sky                                          0.9714           29.27
# 62           Snow                                         0.0000            0.00
# 63           Terrain                                      0.0000            0.00
# 64           Vegetation                                   0.8602           14.81
# 65           Water                                        0.0000            0.00
# 66           Banner                                       0.0000            0.00
# 67           Bench                                        0.0000            0.00
# 68           Bike Rack                                    0.0000            0.00
# 69           Catch Basin                                  0.0000            0.00
# 70           CCTV Camera                                  0.0000            0.00
# 71           Fire Hydrant                                 0.0000            0.00
# 72           Junction Box                                 0.0000            0.00
# 73           Mailbox                                      0.0000            0.00
# 74           Manhole                                      0.0000            0.00
# 75           Parking Meter                                0.0000            0.00
# 76           Phone Booth                                  0.0000            0.00
# 77           Pothole                                      0.0000            0.00
# 78           Signage - Advertisement                      0.0000            0.00
# 79           Signage - Ambiguous                          0.0000            0.00
# 80           Signage - Back                               0.0000            0.00
# 81           Signage - Information                        0.0000            0.00
# 82           Signage - Other                              0.0000            0.00
# 83           Signage - Store                              0.0000            0.00
# 84           Street Light                                 0.2425            0.06
# 85           Pole                                         0.2808            0.85
# 86           Pole Group                                   0.0038            0.01
# 87           Traffic Sign Frame                           0.0000            0.00
# 88           Utility Pole                                 0.0000            0.00
# 89           Traffic Cone                                 0.0000            0.00
# 90           Traffic Light - General (Single)             0.0000            0.00
# 91           Traffic Light - Pedestrians                  0.1125            0.03
# 92           Traffic Light - General (Upright)            0.4803            0.13
# 93           Traffic Light - General (Horizontal)         0.2669            0.01
# 94           Traffic Light - Cyclists                     0.0004            0.00
# 95           Traffic Light - Other                        0.0000            0.00
# 96           Traffic Sign - Ambiguous                     0.0000            0.00
# 97           Traffic Sign (Back)                          0.0000            0.00
# 98           Traffic Sign - Direction (Back)              0.0000            0.00
# 99           Traffic Sign - Direction (Front)             0.6110            0.22
# 100          Traffic Sign (Front)                         0.4796            0.25
# 101          Traffic Sign - Parking                       0.0000            0.00
# 102          Traffic Sign - Temporary (Back)              0.0000            0.00
# 103          Traffic Sign - Temporary (Front)             0.0475            0.01
# 104          Trash Can                                    0.0000            0.00
# 105          Bicycle                                      0.4206            0.05
# 106          Boat                                         0.0000            0.00
# 107          Bus                                          0.5627            0.23
# 108          Car                                          0.8445            3.38
# 109          Caravan                                      0.0000            0.00
# 110          Motorcycle                                   0.4524            0.06
# 111          On Rails                                     0.0589            0.03
# 112          Other Vehicle                                0.0954            0.04
# 113          Trailer                                      0.0000            0.00
# 114          Truck                                        0.5701            0.36
# 115          Vehicle Group                                0.0000            0.00
# 116          Wheeled Slow                                 0.0001            0.01
# 117          Water Valve                                  0.0000            0.00
# 118          Car Mount                                    0.0000            0.00
# 119          Dynamic                                      0.0000            0.00
# 120          Ego Vehicle                                  0.0000            0.00
# 121          Ground                                       0.0000            0.00
# 122          Static                                       0.0000            0.00
# 123          Unlabeled                                    0.5556            8.34
#
#
# ======================================================================
# Model: deeplabv3_resnet101
# Mean IoU: 0.1527
# FWIoU: 0.8085
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            Bird                                         0.0000            0.00
# 1            Ground Animal                                0.0000            0.00
# 2            Ambiguous Barrier                            0.0000            0.00
# 3            Concrete Block                               0.5906            0.31
# 4            Curb                                         0.4682            0.85
# 5            Fence                                        0.4608            1.27
# 6            Guard Rail                                   0.5899            0.24
# 7            Barrier                                      0.0000            0.00
# 8            Road Median                                  0.0000            0.00
# 9            Road Side                                    0.0000            0.00
# 10           Lane Separator                               0.0000            0.00
# 11           Temporary Barrier                            0.1622            0.02
# 12           Wall                                         0.4160            0.90
# 13           Bike Lane                                    0.3553            0.38
# 14           Crosswalk - Plain                            0.2540            0.25
# 15           Curb Cut                                     0.0516            0.09
# 16           Driveway                                     0.0608            0.16
# 17           Parking                                      0.0000            0.00
# 18           Parking Aisle                                0.0000            0.00
# 19           Pedestrian Area                              0.4591            0.57
# 20           Rail Track                                   0.0000            0.00
# 21           Road                                         0.8526           18.63
# 22           Road Shoulder                                0.1970            0.12
# 23           Service Lane                                 0.0000            0.00
# 24           Sidewalk                                     0.5982            3.15
# 25           Traffic Island                               0.2646            0.31
# 26           Bridge                                       0.0000            0.00
# 27           Building                                     0.8203           12.08
# 28           Garage                                       0.0000            0.00
# 29           Tunnel                                       0.0000            0.00
# 30           Person                                       0.5379            0.31
# 31           Person Group                                 0.0024            0.02
# 32           Bicyclist                                    0.3097            0.03
# 33           Motorcyclist                                 0.2846            0.02
# 34           Other Rider                                  0.0000            0.00
# 35           Lane Marking - Dashed Line                   0.3205            0.28
# 36           Lane Marking - Straight Line                 0.5061            0.52
# 37           Lane Marking - Zigzag Line                   0.0000            0.00
# 38           Lane Marking - Ambiguous                     0.0000            0.01
# 39           Lane Marking - Arrow (Left)                  0.0905            0.01
# 40           Lane Marking - Arrow (Other)                 0.0000            0.01
# 41           Lane Marking - Arrow (Right)                 0.0000            0.01
# 42           Lane Marking - Arrow (Split Left or Straight)     0.0000            0.01
# 43           Lane Marking - Arrow (Split Right or Straight)     0.0002            0.01
# 44           Lane Marking - Arrow (Straight)              0.2781            0.02
# 45           Lane Marking - Crosswalk                     0.6713            0.79
# 46           Lane Marking - Give Way (Row)                0.0000            0.01
# 47           Lane Marking - Give Way (Single)             0.0000            0.00
# 48           Lane Marking - Hatched (Chevron)             0.1017            0.04
# 49           Lane Marking - Hatched (Diagonal)            0.3777            0.12
# 50           Lane Marking - Other                         0.2392            0.13
# 51           Lane Marking - Stop Line                     0.2859            0.08
# 52           Lane Marking - Symbol (Bicycle)              0.3867            0.02
# 53           Lane Marking - Symbol (Other)                0.0000            0.02
# 54           Lane Marking - Text                          0.3975            0.08
# 55           Lane Marking (only) - Dashed Line            0.0000            0.00
# 56           Lane Marking (only) - Crosswalk              0.0000            0.00
# 57           Lane Marking (only) - Other                  0.0000            0.00
# 58           Lane Marking (only) - Test                   0.0000            0.00
# 59           Mountain                                     0.0000            0.00
# 60           Sand                                         0.0000            0.00
# 61           Sky                                          0.9715           29.27
# 62           Snow                                         0.0000            0.00
# 63           Terrain                                      0.0000            0.00
# 64           Vegetation                                   0.8583           14.81
# 65           Water                                        0.0000            0.00
# 66           Banner                                       0.0000            0.00
# 67           Bench                                        0.0000            0.00
# 68           Bike Rack                                    0.0000            0.00
# 69           Catch Basin                                  0.0000            0.00
# 70           CCTV Camera                                  0.0000            0.00
# 71           Fire Hydrant                                 0.0000            0.00
# 72           Junction Box                                 0.0000            0.00
# 73           Mailbox                                      0.0000            0.00
# 74           Manhole                                      0.0000            0.00
# 75           Parking Meter                                0.0000            0.00
# 76           Phone Booth                                  0.0000            0.00
# 77           Pothole                                      0.0000            0.00
# 78           Signage - Advertisement                      0.0000            0.00
# 79           Signage - Ambiguous                          0.0000            0.00
# 80           Signage - Back                               0.0000            0.00
# 81           Signage - Information                        0.0000            0.00
# 82           Signage - Other                              0.0000            0.00
# 83           Signage - Store                              0.0000            0.00
# 84           Street Light                                 0.2478            0.06
# 85           Pole                                         0.2796            0.85
# 86           Pole Group                                   0.0000            0.01
# 87           Traffic Sign Frame                           0.0000            0.00
# 88           Utility Pole                                 0.0000            0.00
# 89           Traffic Cone                                 0.0000            0.00
# 90           Traffic Light - General (Single)             0.0000            0.00
# 91           Traffic Light - Pedestrians                  0.0602            0.03
# 92           Traffic Light - General (Upright)            0.4591            0.13
# 93           Traffic Light - General (Horizontal)         0.0779            0.01
# 94           Traffic Light - Cyclists                     0.0000            0.00
# 95           Traffic Light - Other                        0.0000            0.00
# 96           Traffic Sign - Ambiguous                     0.0000            0.00
# 97           Traffic Sign (Back)                          0.0000            0.00
# 98           Traffic Sign - Direction (Back)              0.0000            0.00
# 99           Traffic Sign - Direction (Front)             0.6096            0.22
# 100          Traffic Sign (Front)                         0.4703            0.25
# 101          Traffic Sign - Parking                       0.0000            0.00
# 102          Traffic Sign - Temporary (Back)              0.0000            0.00
# 103          Traffic Sign - Temporary (Front)             0.0476            0.01
# 104          Trash Can                                    0.0000            0.00
# 105          Bicycle                                      0.3937            0.05
# 106          Boat                                         0.0000            0.00
# 107          Bus                                          0.6346            0.23
# 108          Car                                          0.8459            3.38
# 109          Caravan                                      0.0000            0.00
# 110          Motorcycle                                   0.4198            0.06
# 111          On Rails                                     0.0066            0.03
# 112          Other Vehicle                                0.0104            0.04
# 113          Trailer                                      0.0000            0.00
# 114          Truck                                        0.5815            0.36
# 115          Vehicle Group                                0.0000            0.00
# 116          Wheeled Slow                                 0.0000            0.01
# 117          Water Valve                                  0.0000            0.00
# 118          Car Mount                                    0.0000            0.00
# 119          Dynamic                                      0.0000            0.00
# 120          Ego Vehicle                                  0.0000            0.00
# 121          Ground                                       0.0000            0.00
# 122          Static                                       0.0000            0.00
# 123          Unlabeled                                    0.5660            8.34
#
#
# ======================================================================
# Model: deeplabv3_resnet50
# Mean IoU: 0.1465
# FWIoU: 0.8030
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            Bird                                         0.0000            0.00
# 1            Ground Animal                                0.0000            0.00
# 2            Ambiguous Barrier                            0.0000            0.00
# 3            Concrete Block                               0.5926            0.31
# 4            Curb                                         0.4606            0.85
# 5            Fence                                        0.4547            1.27
# 6            Guard Rail                                   0.5745            0.24
# 7            Barrier                                      0.0000            0.00
# 8            Road Median                                  0.0000            0.00
# 9            Road Side                                    0.0000            0.00
# 10           Lane Separator                               0.0000            0.00
# 11           Temporary Barrier                            0.1671            0.02
# 12           Wall                                         0.3918            0.90
# 13           Bike Lane                                    0.3615            0.38
# 14           Crosswalk - Plain                            0.2194            0.25
# 15           Curb Cut                                     0.0375            0.09
# 16           Driveway                                     0.0415            0.16
# 17           Parking                                      0.0000            0.00
# 18           Parking Aisle                                0.0000            0.00
# 19           Pedestrian Area                              0.3815            0.57
# 20           Rail Track                                   0.0000            0.00
# 21           Road                                         0.8457           18.63
# 22           Road Shoulder                                0.1758            0.12
# 23           Service Lane                                 0.0000            0.00
# 24           Sidewalk                                     0.5812            3.15
# 25           Traffic Island                               0.2307            0.31
# 26           Bridge                                       0.0000            0.00
# 27           Building                                     0.8180           12.08
# 28           Garage                                       0.0000            0.00
# 29           Tunnel                                       0.0000            0.00
# 30           Person                                       0.5297            0.31
# 31           Person Group                                 0.0011            0.02
# 32           Bicyclist                                    0.3285            0.03
# 33           Motorcyclist                                 0.2572            0.02
# 34           Other Rider                                  0.0000            0.00
# 35           Lane Marking - Dashed Line                   0.2957            0.28
# 36           Lane Marking - Straight Line                 0.4945            0.52
# 37           Lane Marking - Zigzag Line                   0.0000            0.00
# 38           Lane Marking - Ambiguous                     0.0000            0.01
# 39           Lane Marking - Arrow (Left)                  0.1052            0.01
# 40           Lane Marking - Arrow (Other)                 0.0000            0.01
# 41           Lane Marking - Arrow (Right)                 0.0000            0.01
# 42           Lane Marking - Arrow (Split Left or Straight)     0.0000            0.01
# 43           Lane Marking - Arrow (Split Right or Straight)     0.0000            0.01
# 44           Lane Marking - Arrow (Straight)              0.2335            0.02
# 45           Lane Marking - Crosswalk                     0.6504            0.79
# 46           Lane Marking - Give Way (Row)                0.0000            0.01
# 47           Lane Marking - Give Way (Single)             0.0000            0.00
# 48           Lane Marking - Hatched (Chevron)             0.0547            0.04
# 49           Lane Marking - Hatched (Diagonal)            0.3919            0.12
# 50           Lane Marking - Other                         0.2352            0.13
# 51           Lane Marking - Stop Line                     0.2655            0.08
# 52           Lane Marking - Symbol (Bicycle)              0.3467            0.02
# 53           Lane Marking - Symbol (Other)                0.0000            0.02
# 54           Lane Marking - Text                          0.3610            0.08
# 55           Lane Marking (only) - Dashed Line            0.0000            0.00
# 56           Lane Marking (only) - Crosswalk              0.0000            0.00
# 57           Lane Marking (only) - Other                  0.0000            0.00
# 58           Lane Marking (only) - Test                   0.0000            0.00
# 59           Mountain                                     0.0000            0.00
# 60           Sand                                         0.0000            0.00
# 61           Sky                                          0.9709           29.27
# 62           Snow                                         0.0000            0.00
# 63           Terrain                                      0.0000            0.00
# 64           Vegetation                                   0.8567           14.81
# 65           Water                                        0.0000            0.00
# 66           Banner                                       0.0000            0.00
# 67           Bench                                        0.0000            0.00
# 68           Bike Rack                                    0.0000            0.00
# 69           Catch Basin                                  0.0000            0.00
# 70           CCTV Camera                                  0.0000            0.00
# 71           Fire Hydrant                                 0.0000            0.00
# 72           Junction Box                                 0.0000            0.00
# 73           Mailbox                                      0.0000            0.00
# 74           Manhole                                      0.0000            0.00
# 75           Parking Meter                                0.0000            0.00
# 76           Phone Booth                                  0.0000            0.00
# 77           Pothole                                      0.0000            0.00
# 78           Signage - Advertisement                      0.0000            0.00
# 79           Signage - Ambiguous                          0.0000            0.00
# 80           Signage - Back                               0.0000            0.00
# 81           Signage - Information                        0.0000            0.00
# 82           Signage - Other                              0.0000            0.00
# 83           Signage - Store                              0.0000            0.00
# 84           Street Light                                 0.2375            0.06
# 85           Pole                                         0.2819            0.85
# 86           Pole Group                                   0.0000            0.01
# 87           Traffic Sign Frame                           0.0000            0.00
# 88           Utility Pole                                 0.0000            0.00
# 89           Traffic Cone                                 0.0000            0.00
# 90           Traffic Light - General (Single)             0.0000            0.00
# 91           Traffic Light - Pedestrians                  0.0450            0.03
# 92           Traffic Light - General (Upright)            0.4451            0.13
# 93           Traffic Light - General (Horizontal)         0.0322            0.01
# 94           Traffic Light - Cyclists                     0.0000            0.00
# 95           Traffic Light - Other                        0.0000            0.00
# 96           Traffic Sign - Ambiguous                     0.0000            0.00
# 97           Traffic Sign (Back)                          0.0000            0.00
# 98           Traffic Sign - Direction (Back)              0.0000            0.00
# 99           Traffic Sign - Direction (Front)             0.6045            0.22
# 100          Traffic Sign (Front)                         0.4663            0.25
# 101          Traffic Sign - Parking                       0.0000            0.00
# 102          Traffic Sign - Temporary (Back)              0.0000            0.00
# 103          Traffic Sign - Temporary (Front)             0.0248            0.01
# 104          Trash Can                                    0.0000            0.00
# 105          Bicycle                                      0.3887            0.05
# 106          Boat                                         0.0000            0.00
# 107          Bus                                          0.5852            0.23
# 108          Car                                          0.8348            3.38
# 109          Caravan                                      0.0000            0.00
# 110          Motorcycle                                   0.3974            0.06
# 111          On Rails                                     0.0015            0.03
# 112          Other Vehicle                                0.0129            0.04
# 113          Trailer                                      0.0000            0.00
# 114          Truck                                        0.5393            0.36
# 115          Vehicle Group                                0.0000            0.00
# 116          Wheeled Slow                                 0.0000            0.01
# 117          Water Valve                                  0.0000            0.00
# 118          Car Mount                                    0.0000            0.00
# 119          Dynamic                                      0.0000            0.00
# 120          Ego Vehicle                                  0.0000            0.00
# 121          Ground                                       0.0000            0.00
# 122          Static                                       0.0000            0.00
# 123          Unlabeled                                    0.5558            8.34
#
#
# ======================================================================
# Model: fcn_resnet50
# Mean IoU: 0.1510
# FWIoU: 0.7959
#
# Per-Klassen Metriken:
# Class Index  Class Name                                      IoU   Frequency (%)
# ----------------------------------------------------------------------
# 0            Bird                                         0.0000            0.00
# 1            Ground Animal                                0.0000            0.00
# 2            Ambiguous Barrier                            0.0000            0.00
# 3            Concrete Block                               0.5857            0.31
# 4            Curb                                         0.4717            0.85
# 5            Fence                                        0.4602            1.27
# 6            Guard Rail                                   0.5853            0.24
# 7            Barrier                                      0.0000            0.00
# 8            Road Median                                  0.0000            0.00
# 9            Road Side                                    0.0000            0.00
# 10           Lane Separator                               0.0000            0.00
# 11           Temporary Barrier                            0.2037            0.02
# 12           Wall                                         0.3976            0.90
# 13           Bike Lane                                    0.2455            0.38
# 14           Crosswalk - Plain                            0.1385            0.25
# 15           Curb Cut                                     0.0671            0.09
# 16           Driveway                                     0.0976            0.16
# 17           Parking                                      0.0000            0.00
# 18           Parking Aisle                                0.0000            0.00
# 19           Pedestrian Area                              0.1499            0.57
# 20           Rail Track                                   0.0000            0.00
# 21           Road                                         0.8280           18.63
# 22           Road Shoulder                                0.1855            0.12
# 23           Service Lane                                 0.0000            0.00
# 24           Sidewalk                                     0.5256            3.15
# 25           Traffic Island                               0.2186            0.31
# 26           Bridge                                       0.0000            0.00
# 27           Building                                     0.8108           12.08
# 28           Garage                                       0.0000            0.00
# 29           Tunnel                                       0.0000            0.00
# 30           Person                                       0.5379            0.31
# 31           Person Group                                 0.0265            0.02
# 32           Bicyclist                                    0.3076            0.03
# 33           Motorcyclist                                 0.2759            0.02
# 34           Other Rider                                  0.0000            0.00
# 35           Lane Marking - Dashed Line                   0.3103            0.28
# 36           Lane Marking - Straight Line                 0.5034            0.52
# 37           Lane Marking - Zigzag Line                   0.0000            0.00
# 38           Lane Marking - Ambiguous                     0.0000            0.01
# 39           Lane Marking - Arrow (Left)                  0.1041            0.01
# 40           Lane Marking - Arrow (Other)                 0.0186            0.01
# 41           Lane Marking - Arrow (Right)                 0.0372            0.01
# 42           Lane Marking - Arrow (Split Left or Straight)     0.0000            0.01
# 43           Lane Marking - Arrow (Split Right or Straight)     0.1479            0.01
# 44           Lane Marking - Arrow (Straight)              0.2793            0.02
# 45           Lane Marking - Crosswalk                     0.6621            0.79
# 46           Lane Marking - Give Way (Row)                0.0000            0.01
# 47           Lane Marking - Give Way (Single)             0.0000            0.00
# 48           Lane Marking - Hatched (Chevron)             0.0934            0.04
# 49           Lane Marking - Hatched (Diagonal)            0.3420            0.12
# 50           Lane Marking - Other                         0.2252            0.13
# 51           Lane Marking - Stop Line                     0.2889            0.08
# 52           Lane Marking - Symbol (Bicycle)              0.3990            0.02
# 53           Lane Marking - Symbol (Other)                0.0000            0.02
# 54           Lane Marking - Text                          0.3810            0.08
# 55           Lane Marking (only) - Dashed Line            0.0000            0.00
# 56           Lane Marking (only) - Crosswalk              0.0000            0.00
# 57           Lane Marking (only) - Other                  0.0000            0.00
# 58           Lane Marking (only) - Test                   0.0000            0.00
# 59           Mountain                                     0.0000            0.00
# 60           Sand                                         0.0000            0.00
# 61           Sky                                          0.9712           29.27
# 62           Snow                                         0.0000            0.00
# 63           Terrain                                      0.0000            0.00
# 64           Vegetation                                   0.8599           14.81
# 65           Water                                        0.0000            0.00
# 66           Banner                                       0.0000            0.00
# 67           Bench                                        0.0000            0.00
# 68           Bike Rack                                    0.0000            0.00
# 69           Catch Basin                                  0.0000            0.00
# 70           CCTV Camera                                  0.0000            0.00
# 71           Fire Hydrant                                 0.0000            0.00
# 72           Junction Box                                 0.0000            0.00
# 73           Mailbox                                      0.0000            0.00
# 74           Manhole                                      0.0000            0.00
# 75           Parking Meter                                0.0000            0.00
# 76           Phone Booth                                  0.0000            0.00
# 77           Pothole                                      0.0000            0.00
# 78           Signage - Advertisement                      0.0000            0.00
# 79           Signage - Ambiguous                          0.0000            0.00
# 80           Signage - Back                               0.0000            0.00
# 81           Signage - Information                        0.0000            0.00
# 82           Signage - Other                              0.0000            0.00
# 83           Signage - Store                              0.0000            0.00
# 84           Street Light                                 0.2344            0.06
# 85           Pole                                         0.2733            0.85
# 86           Pole Group                                   0.0009            0.01
# 87           Traffic Sign Frame                           0.0000            0.00
# 88           Utility Pole                                 0.0000            0.00
# 89           Traffic Cone                                 0.0000            0.00
# 90           Traffic Light - General (Single)             0.0000            0.00
# 91           Traffic Light - Pedestrians                  0.0940            0.03
# 92           Traffic Light - General (Upright)            0.4713            0.13
# 93           Traffic Light - General (Horizontal)         0.2187            0.01
# 94           Traffic Light - Cyclists                     0.0000            0.00
# 95           Traffic Light - Other                        0.0000            0.00
# 96           Traffic Sign - Ambiguous                     0.0000            0.00
# 97           Traffic Sign (Back)                          0.0000            0.00
# 98           Traffic Sign - Direction (Back)              0.0000            0.00
# 99           Traffic Sign - Direction (Front)             0.6258            0.22
# 100          Traffic Sign (Front)                         0.4760            0.25
# 101          Traffic Sign - Parking                       0.0000            0.00
# 102          Traffic Sign - Temporary (Back)              0.0000            0.00
# 103          Traffic Sign - Temporary (Front)             0.0542            0.01
# 104          Trash Can                                    0.0000            0.00
# 105          Bicycle                                      0.4237            0.05
# 106          Boat                                         0.0000            0.00
# 107          Bus                                          0.6098            0.23
# 108          Car                                          0.8456            3.38
# 109          Caravan                                      0.0000            0.00
# 110          Motorcycle                                   0.4360            0.06
# 111          On Rails                                     0.0673            0.03
# 112          Other Vehicle                                0.0443            0.04
# 113          Trailer                                      0.0000            0.00
# 114          Truck                                        0.5519            0.36
# 115          Vehicle Group                                0.0000            0.00
# 116          Wheeled Slow                                 0.0073            0.01
# 117          Water Valve                                  0.0000            0.00
# 118          Car Mount                                    0.0000            0.00
# 119          Dynamic                                      0.0000            0.00
# 120          Ego Vehicle                                  0.0000            0.00
# 121          Ground                                       0.0000            0.00
# 122          Static                                       0.0000            0.00
# 123          Unlabeled                                    0.5450            8.34
#
#
# Ergebnisse wurden in JSON gespeichert: /home/jan/studienarbeit/Studienarbeit-CODE_Semantische_Segmentation/FINAL_DATEN/iou_per_class_results_map_small.json
